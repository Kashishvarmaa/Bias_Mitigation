# %%
import pandas as pd

# %%
# Load the dataset
file_path = 'CSV/Combined_Dataset.csv'
df = pd.read_csv(file_path)

# %%
df.head(2)
# Out:
#             USN  Gender  Age 12th marks % rural/ urban area Section  \
# 0  1RVU23BSC147    Male   18           75             Urban   IDA_C
# 1  1RVUBSC23016  Female   23           74             Urban   IDA_B
#
#                                Why take this course?  \
# 0  Fulfills general curriculum/education requirem...
# 1  Fulfills general curriculum/education requirem...
#
#         Which teaching methods helped your learning?  \
# 0  Lectures, including online lectures;Class disc...
# 1  Lectures, including online lectures;Class disc...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                Yes
# 1                                                 No
#
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                                 R3
# 1                                                 R4
#
# ...

# %%
# Drop unnecesary columns 
drop_columns = ['USN','Section' ]
df.drop(columns=drop_columns, inplace=True)

# %%
df.head()
# Out:
#    Gender  Age 12th marks % rural/ urban area  \
# 0    Male   18           75             Urban
# 1  Female   23           74             Urban
# 2    Male   20           65             Rural
# 3  Female   20           72             Urban
# 4    Male   18         70.4             Urban
#
#                                Why take this course?  \
# 0  Fulfills general curriculum/education requirem...
# 1  Fulfills general curriculum/education requirem...
# 2  Fulfills general curriculum/education requirem...
# 3  Fulfills general curriculum/education requirem...
# 4                            Interest in the subject
#
#         Which teaching methods helped your learning?  \
# 0  Lectures, including online lectures;Class disc...
# 1  Lectures, including online lectures;Class disc...
# 2  Lectures, including online lectures;Class disc...
# 3  Lectures, including online lectures;Class disc...
# 4  Lectures, including online lectures;Class disc...
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
le = LabelEncoder()

# Loop through each column in the DataFrame
for column in df.columns:
    df[column] = le.fit_transform(df[column])

# %%
df
# Out:
#      Gender  Age  12th marks %  rural/ urban area  Why take this course?  \
# 0         1    2            34                  1                     14
# 1         0    6            33                  1                     11
# 2         1    4            12                  0                     19
# 3         0    4            26                  1                      3
# 4         1    2            21                  1                     26
# ..      ...  ...           ...                ...                    ...
# 283       0    2            64                  1                     26
# 284       1    2            19                  1                     26
# 285       0    3            63                  1                     11
# 286       0    1            16                  1                     32
# 287       0    2            77                  1                     11
#
#      Which teaching methods helped your learning?  \
# ...

# %%
# Save the scaled DataFrame to a CSV file
df.to_csv('StudentFeedback_changed.csv', index=False)

# Display a message confirming the save
print("Scaled DataFrame saved to 'scaled_data.csv'")
# Out:
# Scaled DataFrame saved to 'scaled_data.csv'

# %%
import pandas as pd

# Assuming your dataset is a DataFrame called df
binary_columns = [col for col in df.columns if df[col].isin([0, 1]).all()]
print("Columns with only 0 or 1:", binary_columns)
# Out:
# Columns with only 0 or 1: ['Gender', 'rural/ urban area', 'Were you prepared to take this course based on prior coursework?', 'Would more faculty concern improve your learning in C01?', 'Would more faculty concern improve your learning in C02?', 'Would more faculty concern improve your learning in C03?', 'Would more faculty concern improve your learning in C04?', 'Would more outside help improve your learning in C01?', 'Would more outside help improve your learning in C02?', 'Would more outside help improve your learning in C03?', 'Would more outside help improve your learning in C04?']

# %%
import pandas as pd

# Assuming your dataset is a DataFrame called df
for column in df.columns:
    print(column)
# Out:
# Gender
# Age
# 12th marks %
# rural/ urban area
# Why take this course?
# Which teaching methods helped your learning?
# Were you prepared to take this course based on prior coursework?
# How much time did you spend weekly on this course outside of class for C01?
# How much time did you spend weekly on this course outside of class for C02?
# How much time did you spend weekly on this course outside of class for C03?
# How much time did you spend weekly on this course outside of class for C04?
# What level have you achieved in the course outcomes for C01?
# What level have you achieved in the course outcomes for C02?
# What level have you achieved in the course outcomes for C03?
# What level have you achieved in the course outcomes for C04?
# What were the key aspects of your efforts in CO1?
# What were the key aspects of your efforts in CO2?
# What were the key aspects of your efforts in CO3?
# What were the key aspects of your efforts in CO4?
# How satisfied are you with C01?
# ...

# %%
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  Why take this course?  \
# 0       1    2            34                  1                     14
# 1       0    6            33                  1                     11
# 2       1    4            12                  0                     19
# 3       0    4            26                  1                      3
# 4       1    2            21                  1                     26
#
#    Which teaching methods helped your learning?  \
# 0                                            73
# 1                                            62
# 2                                            46
# 3                                            38
# 4                                            72
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# ...

# %%
import pandas as pd

# Adjust display settings to show all columns
pd.set_option('display.max_columns', None)

# Print the descriptive statistics for all columns
df.describe(include='all')
# Out:
#            Gender         Age  12th marks %  rural/ urban area  \
# count  288.000000  288.000000    288.000000         288.000000
# mean     0.461806    2.354167     43.940972           0.878472
# std      0.499407    0.800425     25.948488           0.327308
# min      0.000000    0.000000      0.000000           0.000000
# 25%      0.000000    2.000000     20.000000           1.000000
# 50%      0.000000    2.000000     41.000000           1.000000
# 75%      1.000000    3.000000     64.250000           1.000000
# max      1.000000    6.000000     97.000000           1.000000
#
#        Why take this course?  Which teaching methods helped your learning?  \
# count             288.000000                                    288.000000
# mean               16.861111                                     60.958333
# std                 9.693283                                     30.684837
# min                 0.000000                                      0.000000
# ...

# %%
import pandas as pd

# Assuming your dataset is a DataFrame called df
min_max = df.agg(['min', 'max'])
min_max
# Out:
#      Gender  Age  12th marks %  rural/ urban area  Why take this course?  \
# min       0    0             0                  0                      0
# max       1    6            97                  1                     36
#
#      Which teaching methods helped your learning?  \
# min                                             0
# max                                           120
#
#      Were you prepared to take this course based on prior coursework?  \
# min                                                  0
# max                                                  1
#
#      How much time did you spend weekly on this course outside of class for C01?  \
# min                                                  0
# max                                                  8
#
#      How much time did you spend weekly on this course outside of class for C02?  \
# min                                                  0
# max                                                  8
#
# ...

# %%
# Assuming your dataset is a DataFrame called df
columns_max_greater_than_6 = [col for col in df.columns if df[col].max() > 6]

# Print each column name on a new line
for col in columns_max_greater_than_6:
    print(col)
# Out:
# 12th marks %
# Why take this course?
# Which teaching methods helped your learning?
# How much time did you spend weekly on this course outside of class for C01?
# How much time did you spend weekly on this course outside of class for C02?
# How much time did you spend weekly on this course outside of class for C03?
# How much time did you spend weekly on this course outside of class for C04?
# What were the key aspects of your efforts in CO1?
# What were the key aspects of your efforts in CO2?
# What were the key aspects of your efforts in CO3?
# What were the key aspects of your efforts in CO4?
# How satisfied are you with C02?
# How satisfied are you with C04?
# Explain briefly your rationale for you choice to the previous question

# %%
# Assuming your dataset is a DataFrame called df
columns_to_drop = [
    "Why take this course?", 
    "Which teaching methods helped your learning?", 
    "Explain briefly your rationale for you choice to the previous question" ]

# Drop the specified columns
df = df.drop(columns=columns_to_drop)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 8
#       2 columns_to_drop = [
#       3     "Why take this course?",
#       4     "Which teaching methods helped your learning?",
#       5     "Explain briefly your rationale for you choice to the previous question" ]
#       7 # Drop the specified columns
# ----> 8 df = df.drop(columns=columns_to_drop)
#
# File ~/Documents/5 Sem/DL/Bias_Mitigation/.conda/lib/python3.11/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
# ...

# %%
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    How much time did you spend weekly on this course outside of class for C01?  \
# 0                                                  2
# 1                                                  3
# 2                                                  4
# 3                                                  1
# ...

# %%
# Assuming your dataset is a DataFrame called df
columns_to_average = [
    "How much time did you spend weekly on this course outside of class for C01?",
    "How much time did you spend weekly on this course outside of class for C02?",
    "How much time did you spend weekly on this course outside of class for C03?",
    "How much time did you spend weekly on this course outside of class for C04?"
]

# Calculate the average and add it as a new column
df["Average Weekly Time Spent"] = df[columns_to_average].mean(axis=1)

# Drop the original columns
df = df.drop(columns=columns_to_average)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 10
#       2 columns_to_average = [
#       3     "How much time did you spend weekly on this course outside of class for C01?",
#       4     "How much time did you spend weekly on this course outside of class for C02?",
#       5     "How much time did you spend weekly on this course outside of class for C03?",
#       6     "How much time did you spend weekly on this course outside of class for C04?"
#       7 ]
#       9 # Calculate the average and add it as a new column
# ---> 10 df["Average Weekly Time Spent"] = df[columns_to_average].mean(axis=1)
#      12 # Drop the original columns
#      13 df = df.drop(columns=columns_to_average)
#
# File ~/Documents/5 Sem/DL/Bias_Mitigation/.conda/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
# ...

# %%
# Display the updated DataFrame
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    What level have you achieved in the course outcomes for C01?  \
# 0                                                  6
# 1                                                  5
# 2                                                  5
# 3                                                  6
# 4                                                  6
# ...

# %%
# Assuming your dataset is a DataFrame called df
columns_to_average = [
    "What level have you achieved in the course outcomes for C01?",
    "What level have you achieved in the course outcomes for C02?",
    "What level have you achieved in the course outcomes for C03?",
    "What level have you achieved in the course outcomes for C04?"  # Fixed the duplicate column name (C01)
]

# Calculate the average and add it as a new column
df["Average Course Outcome Level"] = df[columns_to_average].mean(axis=1)

# Drop the original columns
df = df.drop(columns=columns_to_average)

# %%
# Display the updated DataFrame
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    What were the key aspects of your efforts in CO1?  \
# 0                                                  5
# 1                                                  5
# 2                                                  0
# 3                                                  7
# 4                                                  9
#
# ...

# %%
# Assuming your dataset is a DataFrame called df
columns_to_average = [
    "What were the key aspects of your efforts in CO1?",
    "What were the key aspects of your efforts in CO2?",
    "What were the key aspects of your efforts in CO3?",
    "What were the key aspects of your efforts in CO4?"
]

# Calculate the average and add it as a new column (if appropriate)
df["Average Effort in Course Outcomes"] = df[columns_to_average].mean(axis=1)

# Drop the original columns
df = df.drop(columns=columns_to_average)

# %%
# Display the updated DataFrame
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    How satisfied are you with C01?  How satisfied are you with C02?  \
# 0                                2                                2
# 1                                0                                1
# 2                                1                                1
# ...

# %%
# Assuming your dataset is a DataFrame called df
columns_to_average = [
    "How satisfied are you with C01?",
    "How satisfied are you with C02?",
    "How satisfied are you with C03?",
    "How satisfied are you with C04?"
]

# Calculate the average satisfaction and add it as a new column
df["Average Satisfaction"] = df[columns_to_average].mean(axis=1)

# Drop the original columns
df = df.drop(columns=columns_to_average)

# %%
# Display the updated DataFrame
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    List strategies for learning the course outcomes for C01  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
# ...

# %%
# Assuming your dataset is a DataFrame called df
columns_to_analyze = [
    "List strategies for learning the course outcomes for C01",
    "List strategies for learning the course outcomes for C02",
    "List strategies for learning the course outcomes for C03",
    "List strategies for learning the course outcomes for C04"
]

# Calculate the average satisfaction and add it as a new column
df["Stratergies"] = df[columns_to_analyze].mean(axis=1)

# Drop the original columns
df = df.drop(columns=columns_to_analyze)

# %%
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    How many marks will you give yourself for C01?  \
# 0                                               3
# 1                                               2
# 2                                               3
# 3                                               4
# 4                                               4
#
# ...

# %%
# Assuming your dataset is a DataFrame called df
columns_to_analyze_marks = [
    "How many marks will you give yourself for C01?",
    "How many marks will you give yourself for C02?",
    "How many marks will you give yourself for C03?",
    "How many marks will you give yourself for C04?"
]

# Calculate the average marks given across these columns (if numeric)
df["Average Marks Given"] = df[columns_to_analyze_marks].mean(axis=1)

# Drop the original columns
df = df.drop(columns=columns_to_analyze_marks)

# %%
# Display the updated DataFrame
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    If your marks are low in C01, who do you blame for your performance?  \
# 0                                                  1
# 1                                                  1
# 2                                                  3
# 3                                                  1
# ...

# %%
# Assuming your dataset is a DataFrame called df
columns_to_analyze_blame = [
    "If your marks are low in C01, who do you blame for your performance?",
    "If your marks are low in C02, who do you blame for your performance?",
    "If your marks are low in C03, who do you blame for your performance?",
    "If your marks are low in C04, who do you blame for your performance?"
]

# Calculate the average marks given across these columns (if numeric)
df["Low mark reason"] = df[columns_to_analyze_blame].mean(axis=1)

# Drop the original columns
df = df.drop(columns=columns_to_analyze_blame)

# %%
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    Would more faculty concern improve your learning in C01?  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
# ...

# %%
# Assuming your dataset is a DataFrame called df
columns_to_concern = [
    'Would more faculty concern improve your learning in C01?',
    'Would more faculty concern improve your learning in C02?',
    'Would more faculty concern improve your learning in C03?',
    'Would more faculty concern improve your learning in C04?'
]

# Calculate the average marks given across these columns (if numeric)
df["Faculty Concern"] = df[columns_to_concern].mean(axis=1)

# Drop the original columns
df = df.drop(columns=columns_to_concern)

# %%
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    Would more outside help improve your learning in C01?  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
# ...

# %%
# Assuming your dataset is a DataFrame called df
columns_to_help = [
    'Would more outside help improve your learning in C01?',
    'Would more outside help improve your learning in C02?',
    'Would more outside help improve your learning in C03?',
    'Would more outside help improve your learning in C04?'
]

# Calculate the average marks given across these columns (if numeric)
df["Outside help"] = df[columns_to_help].mean(axis=1)

# Drop the original columns
df = df.drop(columns=columns_to_help)

# %%
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    Your overall feedback  Average Weekly Time Spent  \
# 0                      0                        2.0
# 1                      1                        5.0
# 2                      0                        4.5
# 3                      0                        1.5
# 4                      0                        1.0
#
# ...

# %%
# Assuming your dataframe is called df
columns = df.columns.tolist()

# Move the 4th column (index 3) to the last position
columns.append(columns.pop(5))

# Reorder the dataframe columns
df = df[columns]

# %%
# Verify the new order
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    Average Weekly Time Spent  Average Course Outcome Level  \
# 0                        2.0                          5.75
# 1                        5.0                          4.75
# 2                        4.5                          4.75
# 3                        1.5                          5.25
# ...

# %%
# Assuming your dataframe is called df
df = df.astype(int)

# %%
df.head()
# Out:
#    Gender  Age  12th marks %  rural/ urban area  \
# 0       1    2            34                  1
# 1       0    6            33                  1
# 2       1    4            12                  0
# 3       0    4            26                  1
# 4       1    2            21                  1
#
#    Were you prepared to take this course based on prior coursework?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    Average Weekly Time Spent  Average Course Outcome Level  \
# 0                          2                             5
# 1                          5                             4
# 2                          4                             4
# 3                          1                             5
# ...

# %%
# Save the scaled DataFrame to a CSV file
df.to_csv('wholevalue.csv', index=False)

# Display a message confirming the save
print("Scaled DataFrame saved to 'scaled_data.csv'")
# Out:
# Scaled DataFrame saved to 'scaled_data.csv'
