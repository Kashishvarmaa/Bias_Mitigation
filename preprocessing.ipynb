# %%
import pandas as pd

# %% [markdown]
# ### CSV 1  - Student Feedback form_IDA1_CS1202 - Student Feedback form_IDA1_CS1202.csv.csv

# %%
data = pd.read_csv('CSV\Student Feedback form_IDA1_CS1202.csv')

# %%
print(data.head(10))
# Out:
#             USN   Gender  Age 12th marks % rural/ urban area  Section  \
# 0   1RVU23BSC147    Male   18           75              Urban   IDA_C
# 1   1RVUBSC23016  Female   23           74              Urban   IDA_B
# 2   1RVU23BSC073    Male   20           65              Rural   IDA_A
# 3            140  Female   20           72              Urban   IDA_B
# 4   1RVU23BSC001    Male   18         70.4              Urban   IDA_B
# 5   1RVU23BSC061    Male   19          83%              Urban   IDA_B
# 6  1RVU23BSC088   Female   18       93.33%              Urban   IDA_C
# 7   1RVU23BSC043  Female   18           91              Urban   IDA_C
# 8   1RVU23BSC134    Male   18          78%              Urban   IDA_C
# 9   1RVU23BSC046    Male   18           70              Urban   IDA_B
#
#                                Why take this course?  \
# 0  Fulfills general curriculum/education requirem...
# 1  Fulfills general curriculum/education requirem...
# 2  Fulfills general curriculum/education requirem...
# 3  Fulfills general curriculum/education requirem...
# 4                            Interest in the subject
# 5  Required (Core) for Program, Minor, or Special...
# 6  Fulfills general curriculum/education requirem...
# 7  Fulfills general curriculum/education requirem...
# 8  Fulfills general curriculum/education requirem...
# 9  Fulfills general curriculum/education requirem...
#
#        Which teaching methods helped your learning?   \
# 0  Lectures, including online lectures;Class disc...
# 1  Lectures, including online lectures;Class disc...
# 2  Lectures, including online lectures;Class disc...
# 3  Lectures, including online lectures;Class disc...
# 4  Lectures, including online lectures;Class disc...
# 5  Lectures, including online lectures;Class disc...
# 6  Lectures, including online lectures;Class disc...
# 7  Lectures, including online lectures;In-class l...
# 8  Lectures, including online lectures;Class disc...
# 9  Lectures, including online lectures;Class disc...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
# 5                                                Yes
# 6                                                 No
# 7                                                 No
# 8                                                 No
# 9                                                Yes
#
#   How much time did you spend weekly on this course outside of class for C01?\n  \
# 0                                                 R3
# 1                                                 R4
# 2                                                 R5
# 3                                                 R2
# 4                                                 R2
# 5                                                 R6
# 6                                                 R1
# 7                                                 R1
# 8                                                 R2
# 9                                                 R2
#
#    ... Explain briefly your rationale for you choice to the previous question  \
# 0  ...  As I enjoyed learning this subject and I learn...
# 1  ...  For any student themselves or the way of teach...
# 2  ...  I will blame myself beacuse the teachers gave ...
# 3  ...                                                Nil
# 4  ...  Understood the subject due to practice and the...
# 5  ...                                                  .
# 6  ...                                                  -
# 7  ...                       The teachers made it simple.
# 8  ...
# 9  ...  I practiced alot and put in effort towards the...
#
#   Would more faculty concern improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
# 5                                                 NO
# 6                                                Yes
# 7                                                 NO
# 8                                                Yes
# 9                                                 NO
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
# 5                                                 NO
# 6                                                Yes
# 7                                                 NO
# 8                                                Yes
# 9                                                 NO
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
# 5                                                 NO
# 6                                                Yes
# 7                                                 NO
# 8                                                Yes
# 9                                                 NO
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
# 5                                                 NO
# 6                                                Yes
# 7                                                 NO
# 8                                                Yes
# 9                                                 NO
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
# 5                                                 NO
# 6                                                Yes
# 7                                                 NO
# 8                                                Yes
# 9                                                 NO
#
#   Would more outside help improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
# 5                                                 NO
# 6                                                Yes
# 7                                                 NO
# 8                                                Yes
# 9                                                 NO
#
#   Would more outside help improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
# 5                                                 NO
# 6                                                Yes
# 7                                                 NO
# 8                                                Yes
# 9                                                 NO
#
#   Would more outside help improve your learning in C04? Your overall feedback
# 0                                                 NO         Excellent (> 90%)
# 1                                                Yes           Good (70 - 90%)
# 2                                                Yes         Excellent (> 90%)
# 3                                                 NO         Excellent (> 90%)
# 4                                                 NO         Excellent (> 90%)
# 5                                                 NO         Excellent (> 90%)
# 6                                                Yes         Excellent (> 90%)
# 7                                                 NO         Excellent (> 90%)
# 8                                                Yes         Excellent (> 90%)
# 9                                                 NO         Excellent (> 90%)
#
# [10 rows x 47 columns]

# %%
print(data.columns)
# Out:
# Index(['USN ', 'Gender', 'Age', '12th marks %', 'rural/ urban area ',
#        'Section', 'Why take this course?',
#        'Which teaching methods helped your learning? ',
#        'Were you prepared to take this course based on prior coursework?',
#        'How much time did you spend weekly on this course outside of class for C01?\n',
#        'How much time did you spend weekly on this course outside of class for C02? ',
#        'How much time did you spend weekly on this course outside of class for C03? ',
#        'How much time did you spend weekly on this course outside of class for C04? ',
#        'What level have you achieved in the course outcomes for C01?',
#        'What level have you achieved in the course outcomes for C02?',
#        'What level have you achieved in the course outcomes for C03?',
#        'What level have you achieved in the course outcomes for C04?',
#        'What were the key aspects of your efforts in CO1?',
#        'What were the key aspects of your efforts in CO2?',
#        'What were the key aspects of your efforts in CO3?',
#        'What were the key aspects of your efforts in CO4?',
#        '\nHow satisfied are you with C01?',
#        '\nHow satisfied are you with C02?',
#        '\nHow satisfied are you with C03?',
#        '\nHow satisfied are you with C04?',
#        'List strategies for learning the course outcomes for C01',
#        'List strategies for learning the course outcomes for C02',
#        'List strategies for learning the course outcomes for C03',
#        'List strategies for learning the course outcomes for C04',
#        'How many marks will you give yourself for C01? \n',
#        'How many marks will you give yourself for C02? \n',
#        'How many marks will you give yourself for C03? \n',
#        'How many marks will you give yourself for C04? \n',
#        'If your marks are low in C01, who do you blame for your performance?',
#        'If your marks are low in C02, who do you blame for your performance?',
#        'If your marks are low in C03, who do you blame for your performance?',
#        'If your marks are low in C04, who do you blame for your performance?',
#        'Explain briefly your rationale for you choice to the previous question',
#        'Would more faculty concern improve your learning in C01?',
#        'Would more faculty concern improve your learning in C02?',
#        'Would more faculty concern improve your learning in C03?',
#        'Would more faculty concern improve your learning in C04?',
#        'Would more outside help improve your learning in C01?',
#        'Would more outside help improve your learning in C02?',
#        'Would more outside help improve your learning in C03?',
#        'Would more outside help improve your learning in C04?',
#        'Your overall feedback '],
#       dtype='object')

# %%
# Print the DataFrame info, which includes column names and data types
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 47 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   USN                                                                           147 non-null    object
#  1   Gender                                                                        147 non-null    object
#  2   Age                                                                           147 non-null    int64
#  3   12th marks %                                                                  147 non-null    object
#  4   rural/ urban area                                                             147 non-null    object
#  5   Section                                                                       147 non-null    object
#  6   Why take this course?                                                         147 non-null    object
#  7   Which teaching methods helped your learning?                                  147 non-null    object
#  8   Were you prepared to take this course based on prior coursework?              147 non-null    object
#  9   How much time did you spend weekly on this course outside of class for C01?
#   147 non-null    object
#  10  How much time did you spend weekly on this course outside of class for C02?   146 non-null    object
#  11  How much time did you spend weekly on this course outside of class for C03?   146 non-null    object
#  12  How much time did you spend weekly on this course outside of class for C04?   146 non-null    object
#  13  What level have you achieved in the course outcomes for C01?                  147 non-null    object
#  14  What level have you achieved in the course outcomes for C02?                  147 non-null    object
#  15  What level have you achieved in the course outcomes for C03?                  147 non-null    object
#  16  What level have you achieved in the course outcomes for C04?                  147 non-null    object
#  17  What were the key aspects of your efforts in CO1?                             147 non-null    object
#  18  What were the key aspects of your efforts in CO2?                             147 non-null    object
#  19  What were the key aspects of your efforts in CO3?                             147 non-null    object
#  20  What were the key aspects of your efforts in CO4?                             146 non-null    object
#  21
# How satisfied are you with C01?                                              147 non-null    object
#  22
# How satisfied are you with C02?                                              147 non-null    object
#  23
# How satisfied are you with C03?                                              147 non-null    object
#  24
# How satisfied are you with C04?                                              147 non-null    object
#  25  List strategies for learning the course outcomes for C01                      147 non-null    object
#  26  List strategies for learning the course outcomes for C02                      147 non-null    object
#  27  List strategies for learning the course outcomes for C03                      147 non-null    object
#  28  List strategies for learning the course outcomes for C04                      147 non-null    object
#  29  How many marks will you give yourself for C01?
#                               147 non-null    int64
#  30  How many marks will you give yourself for C02?
#                               147 non-null    int64
#  31  How many marks will you give yourself for C03?
#                               147 non-null    int64
#  32  How many marks will you give yourself for C04?
#                               147 non-null    int64
#  33  If your marks are low in C01, who do you blame for your performance?          147 non-null    object
#  34  If your marks are low in C02, who do you blame for your performance?          147 non-null    object
#  35  If your marks are low in C03, who do you blame for your performance?          147 non-null    object
#  36  If your marks are low in C04, who do you blame for your performance?          147 non-null    object
#  37  Explain briefly your rationale for you choice to the previous question        141 non-null    object
#  38  Would more faculty concern improve your learning in C01?                      147 non-null    object
#  39  Would more faculty concern improve your learning in C02?                      147 non-null    object
#  40  Would more faculty concern improve your learning in C03?                      147 non-null    object
#  41  Would more faculty concern improve your learning in C04?                      147 non-null    object
#  42  Would more outside help improve your learning in C01?                         147 non-null    object
#  43  Would more outside help improve your learning in C02?                         147 non-null    object
#  44  Would more outside help improve your learning in C03?                         147 non-null    object
#  45  Would more outside help improve your learning in C04?                         147 non-null    object
#  46  Your overall feedback                                                         147 non-null    object
# dtypes: int64(5), object(42)
# memory usage: 54.1+ KB
# None

# %% [markdown]
# Replacing R1-R5 with values

# %%
# Strip whitespace and newline characters from all column names
data.columns = data.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping = {
    'R1': 'Less than one hour',
    'R2': '1-2 hours',
    'R3': '3-4 hours',
    'R4': '5-6 hours',
    'R5': '7-8 hours',
    'R6': '9-10 hours',
    'R7': '11-12 hours',
    'R8': '13-15 hours',
    'R9': 'More than 15 hours'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify = [
    'How much time did you spend weekly on this course outside of class for C01?',
    'How much time did you spend weekly on this course outside of class for C02?',
    'How much time did you spend weekly on this course outside of class for C03?',
    'How much time did you spend weekly on this course outside of class for C04?'
]

# Replace the values in the specified columns
for column in columns_to_modify:
    if column in data.columns:
        data[column] = data[column].replace(value_mapping)

# %%
print(data[columns_to_modify].head())
# Out:
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          3-4 hours
# 1                                          5-6 hours
# 2                                          7-8 hours
# 3                                          1-2 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C02?  \
# 0                                          3-4 hours
# 1                                          7-8 hours
# 2                                          7-8 hours
# 3                                          1-2 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C03?  \
# 0                                          3-4 hours
# 1                                        11-12 hours
# 2                                         9-10 hours
# 3                                          3-4 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C04?
# 0                                          3-4 hours
# 1                                        13-15 hours
# 2                                         9-10 hours
# 3                                          3-4 hours
# 4                                          1-2 hours

# %%
print(data.columns)
# Out:
# Index(['USN', 'Gender', 'Age', '12th marks %', 'rural/ urban area', 'Section',
#        'Why take this course?', 'Which teaching methods helped your learning?',
#        'Were you prepared to take this course based on prior coursework?',
#        'How much time did you spend weekly on this course outside of class for C01?',
#        'How much time did you spend weekly on this course outside of class for C02?',
#        'How much time did you spend weekly on this course outside of class for C03?',
#        'How much time did you spend weekly on this course outside of class for C04?',
#        'What level have you achieved in the course outcomes for C01?',
#        'What level have you achieved in the course outcomes for C02?',
#        'What level have you achieved in the course outcomes for C03?',
#        'What level have you achieved in the course outcomes for C04?',
#        'What were the key aspects of your efforts in CO1?',
#        'What were the key aspects of your efforts in CO2?',
#        'What were the key aspects of your efforts in CO3?',
#        'What were the key aspects of your efforts in CO4?',
#        'How satisfied are you with C01?', 'How satisfied are you with C02?',
#        'How satisfied are you with C03?', 'How satisfied are you with C04?',
#        'List strategies for learning the course outcomes for C01',
#        'List strategies for learning the course outcomes for C02',
#        'List strategies for learning the course outcomes for C03',
#        'List strategies for learning the course outcomes for C04',
#        'How many marks will you give yourself for C01?',
#        'How many marks will you give yourself for C02?',
#        'How many marks will you give yourself for C03?',
#        'How many marks will you give yourself for C04?',
#        'If your marks are low in C01, who do you blame for your performance?',
#        'If your marks are low in C02, who do you blame for your performance?',
#        'If your marks are low in C03, who do you blame for your performance?',
#        'If your marks are low in C04, who do you blame for your performance?',
#        'Explain briefly your rationale for you choice to the previous question',
#        'Would more faculty concern improve your learning in C01?',
#        'Would more faculty concern improve your learning in C02?',
#        'Would more faculty concern improve your learning in C03?',
#        'Would more faculty concern improve your learning in C04?',
#        'Would more outside help improve your learning in C01?',
#        'Would more outside help improve your learning in C02?',
#        'Would more outside help improve your learning in C03?',
#        'Would more outside help improve your learning in C04?',
#        'Your overall feedback'],
#       dtype='object')

# %%
# Strip whitespace and newline characters from all column names
data.columns = data.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping = {
    'R1': 'Memorizing facts and repeating ideas from the readings and lectures',
    'R2': 'Applying basic elements of an idea, experience, or theory',
    'R3': 'Synthesizing and organizing ideas, information, or experiences',
    'R4': 'Making judgments about the value of information, arguments, or methods',
    'R5': 'Applying theories or concepts to practical problems or in new situations',
    'R6': 'Solving problems',
    'R7': 'Thinking creatively or critically',
    'R8': 'Teamwork or group activities',
    'R9': 'Reading for deep understanding',
    'R10': 'Presenting in person or via a recording',
    'R8': 'Doing lab work',
    'R9': 'Writing'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify = [
     'What level have you achieved in the course outcomes for C01?',
       'What level have you achieved in the course outcomes for C02?',
       'What level have you achieved in the course outcomes for C03?',
       'What level have you achieved in the course outcomes for C04?'
]

# Replace the values in the specified columns
for column in columns_to_modify:
    if column in data.columns:
        data[column] = data[column].replace(value_mapping)

# %%
# Print the modified columns to verify the changes
print(data[columns_to_modify].head())
# Out:
#   What level have you achieved in the course outcomes for C01?  \
# 0                  Thinking creatively or critically
# 1                                   Solving problems
# 2                                   Solving problems
# 3                  Thinking creatively or critically
# 4                  Thinking creatively or critically
#
#   What level have you achieved in the course outcomes for C02?  \
# 0                  Thinking creatively or critically
# 1                                   Solving problems
# 2                                   Solving problems
# 3                  Thinking creatively or critically
# 4                  Thinking creatively or critically
#
#   What level have you achieved in the course outcomes for C03?  \
# 0                  Thinking creatively or critically
# 1                                   Solving problems
# 2                                   Solving problems
# 3                                   Solving problems
# 4                  Thinking creatively or critically
#
#   What level have you achieved in the course outcomes for C04?
# 0                  Thinking creatively or critically
# 1                                   Solving problems
# 2                                   Solving problems
# 3                                   Solving problems
# 4                  Thinking creatively or critically

# %%
# Strip whitespace and newline characters from all column names (if not already done)
data.columns = data.columns.str.strip()

# Define the columns to delete
columns_to_delete = [
    'What were the key aspects of your efforts in CO1?',
    'What were the key aspects of your efforts in CO2?',
    'What were the key aspects of your efforts in CO3?',
    'What were the key aspects of your efforts in CO4?'
]

# Drop the columns from the DataFrame
data = data.drop(columns=columns_to_delete)

# Print the DataFrame to verify the columns are deleted
print(data.head())
# Out:
#             USN  Gender  Age 12th marks % rural/ urban area Section  \
# 0  1RVU23BSC147    Male   18           75             Urban   IDA_C
# 1  1RVUBSC23016  Female   23           74             Urban   IDA_B
# 2  1RVU23BSC073    Male   20           65             Rural   IDA_A
# 3           140  Female   20           72             Urban   IDA_B
# 4  1RVU23BSC001    Male   18         70.4             Urban   IDA_B
#
#                                Why take this course?  \
# 0  Fulfills general curriculum/education requirem...
# 1  Fulfills general curriculum/education requirem...
# 2  Fulfills general curriculum/education requirem...
# 3  Fulfills general curriculum/education requirem...
# 4                            Interest in the subject
#
#         Which teaching methods helped your learning?  \
# 0  Lectures, including online lectures;Class disc...
# 1  Lectures, including online lectures;Class disc...
# 2  Lectures, including online lectures;Class disc...
# 3  Lectures, including online lectures;Class disc...
# 4  Lectures, including online lectures;Class disc...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          3-4 hours
# 1                                          5-6 hours
# 2                                          7-8 hours
# 3                                          1-2 hours
# 4                                          1-2 hours
#
#    ... Explain briefly your rationale for you choice to the previous question  \
# 0  ...  As I enjoyed learning this subject and I learn...
# 1  ...  For any student themselves or the way of teach...
# 2  ...  I will blame myself beacuse the teachers gave ...
# 3  ...                                                Nil
# 4  ...  Understood the subject due to practice and the...
#
#   Would more faculty concern improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C04? Your overall feedback
# 0                                                 NO        Excellent (> 90%)
# 1                                                Yes          Good (70 - 90%)
# 2                                                Yes        Excellent (> 90%)
# 3                                                 NO        Excellent (> 90%)
# 4                                                 NO        Excellent (> 90%)
#
# [5 rows x 43 columns]

# %%
# Strip whitespace and newline characters from all column names
data.columns = data.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping = {
    'R1': 'Happy as I put in the required effort',
    'R2': 'Happy as I understood the teacher',
    'R3': 'Happy as I enjoyed doing the CO activities',
    'R4': 'Neutral with my effort',
    'R5': 'Neutral about understanding the teacher',
    'R6': 'Neutral about the activities',
    'R7': 'Not happy as I did not put in the required effort',
    'R8': 'Not happy as I could not understand the teacher',
    'R9': 'Not happy as the CO activities were boring' 
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify = [
     'How satisfied are you with C01?', 'How satisfied are you with C02?',
       'How satisfied are you with C03?', 'How satisfied are you with C04?'
]

# Replace the values in the specified columns
for column in columns_to_modify:
    if column in data.columns:
        data[column] = data[column].replace(value_mapping)

# %%
# Print the modified columns to verify the changes
print(data[columns_to_modify].head())
# Out:
#               How satisfied are you with C01?  \
# 0  Happy as I enjoyed doing the CO activities
# 1       Happy as I put in the required effort
# 2           Happy as I understood the teacher
# 3       Happy as I put in the required effort
# 4  Happy as I enjoyed doing the CO activities
#
#               How satisfied are you with C02?  \
# 0  Happy as I enjoyed doing the CO activities
# 1           Happy as I understood the teacher
# 2           Happy as I understood the teacher
# 3           Happy as I understood the teacher
# 4  Happy as I enjoyed doing the CO activities
#
#               How satisfied are you with C03?  \
# 0  Happy as I enjoyed doing the CO activities
# 1  Happy as I enjoyed doing the CO activities
# 2           Happy as I understood the teacher
# 3  Happy as I enjoyed doing the CO activities
# 4  Happy as I enjoyed doing the CO activities
#
#               How satisfied are you with C04?
# 0  Happy as I enjoyed doing the CO activities
# 1  Happy as I enjoyed doing the CO activities
# 2           Happy as I understood the teacher
# 3  Happy as I enjoyed doing the CO activities
# 4  Happy as I enjoyed doing the CO activities

# %%
 # Strip whitespace and newline characters from all column names
data.columns = data.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping = {
    'R1': 'Copy-paste friends work',
    'R2': 'Copy-paste from online',
    'R3': 'Understand others work but redo it, referring to it',
    'R4': 'Understand others work but redo it, without referring to it',
    'R5': 'Try by myself and get it reviewed by peers/teaching assistants/teachers'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify = [
     'List strategies for learning the course outcomes for C01',
       'List strategies for learning the course outcomes for C02',
       'List strategies for learning the course outcomes for C03',
       'List strategies for learning the course outcomes for C04'
]

# Replace the values in the specified columns
for column in columns_to_modify:
    if column in data.columns:
        data[column] = data[column].replace(value_mapping)

# %%
# Print the modified columns to verify the changes
print(data[columns_to_modify].head())
# Out:
#   List strategies for learning the course outcomes for C01  \
# 0  Understand others work but redo it, without re...
# 1  Understand others work but redo it, without re...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, without re...
# 4  Try by myself and get it reviewed by peers/tea...
#
#   List strategies for learning the course outcomes for C02  \
# 0  Understand others work but redo it, without re...
# 1  Understand others work but redo it, without re...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, without re...
# 4  Try by myself and get it reviewed by peers/tea...
#
#   List strategies for learning the course outcomes for C03  \
# 0  Understand others work but redo it, without re...
# 1  Understand others work but redo it, without re...
# 2  Understand others work but redo it, without re...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Try by myself and get it reviewed by peers/tea...
#
#   List strategies for learning the course outcomes for C04
# 0  Understand others work but redo it, without re...
# 1  Understand others work but redo it, without re...
# 2  Understand others work but redo it, without re...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Try by myself and get it reviewed by peers/tea...

# %%
 # Strip whitespace and newline characters from all column names
data.columns = data.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping = {
    'R1': 'Copy-paste friends work',
    'R2': 'Copy-paste from online',
    'R3': 'Understand others work but redo it, referring to it',
    'R4': 'Understand others work but redo it, without referring to it',
    'R5': 'Try by myself and get it reviewed by peers/teaching assistants/teachers'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify = [
     'List strategies for learning the course outcomes for C01',
       'List strategies for learning the course outcomes for C02',
       'List strategies for learning the course outcomes for C03',
       'List strategies for learning the course outcomes for C04'
]

# Replace the values in the specified columns
for column in columns_to_modify:
    if column in data.columns:
        data[column] = data[column].replace(value_mapping)

# %%
# Print the modified columns to verify the changes
print(data[columns_to_modify].head())
# Out:
#   List strategies for learning the course outcomes for C01  \
# 0  Understand others work but redo it, without re...
# 1  Understand others work but redo it, without re...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, without re...
# 4  Try by myself and get it reviewed by peers/tea...
#
#   List strategies for learning the course outcomes for C02  \
# 0  Understand others work but redo it, without re...
# 1  Understand others work but redo it, without re...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, without re...
# 4  Try by myself and get it reviewed by peers/tea...
#
#   List strategies for learning the course outcomes for C03  \
# 0  Understand others work but redo it, without re...
# 1  Understand others work but redo it, without re...
# 2  Understand others work but redo it, without re...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Try by myself and get it reviewed by peers/tea...
#
#   List strategies for learning the course outcomes for C04
# 0  Understand others work but redo it, without re...
# 1  Understand others work but redo it, without re...
# 2  Understand others work but redo it, without re...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Try by myself and get it reviewed by peers/tea...

# %%
 # Strip whitespace and newline characters from all column names
data.columns = data.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping = {
    'R1': 'Copy-paste friends work',
    'R2': 'Copy-paste from online',
    'R3': 'Understand others work but redo it, referring to it',
    'R4': 'Understand others work but redo it, without referring to it',
    'R5': 'Try by myself and get it reviewed by peers/teaching assistants/teachers'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify = [
     'List strategies for learning the course outcomes for C01',
       'List strategies for learning the course outcomes for C02',
       'List strategies for learning the course outcomes for C03',
       'List strategies for learning the course outcomes for C04'
]

# Replace the values in the specified columns
for column in columns_to_modify:
    if column in data.columns:
        data[column] = data[column].replace(value_mapping)

# %%
data.head()
# Out:
#             USN  Gender  Age 12th marks % rural/ urban area Section  \
# 0  1RVU23BSC147    Male   18           75             Urban   IDA_C
# 1  1RVUBSC23016  Female   23           74             Urban   IDA_B
# 2  1RVU23BSC073    Male   20           65             Rural   IDA_A
# 3           140  Female   20           72             Urban   IDA_B
# 4  1RVU23BSC001    Male   18         70.4             Urban   IDA_B
#
#                                Why take this course?  \
# 0  Fulfills general curriculum/education requirem...
# 1  Fulfills general curriculum/education requirem...
# 2  Fulfills general curriculum/education requirem...
# 3  Fulfills general curriculum/education requirem...
# 4                            Interest in the subject
#
#         Which teaching methods helped your learning?  \
# 0  Lectures, including online lectures;Class disc...
# 1  Lectures, including online lectures;Class disc...
# 2  Lectures, including online lectures;Class disc...
# 3  Lectures, including online lectures;Class disc...
# 4  Lectures, including online lectures;Class disc...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          3-4 hours
# 1                                          5-6 hours
# 2                                          7-8 hours
# 3                                          1-2 hours
# 4                                          1-2 hours
#
#    ... Explain briefly your rationale for you choice to the previous question  \
# 0  ...  As I enjoyed learning this subject and I learn...
# 1  ...  For any student themselves or the way of teach...
# 2  ...  I will blame myself beacuse the teachers gave ...
# 3  ...                                                Nil
# 4  ...  Understood the subject due to practice and the...
#
#   Would more faculty concern improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C04? Your overall feedback
# 0                                                 NO        Excellent (> 90%)
# 1                                                Yes          Good (70 - 90%)
# 2                                                Yes        Excellent (> 90%)
# 3                                                 NO        Excellent (> 90%)
# 4                                                 NO        Excellent (> 90%)
#
# [5 rows x 43 columns]

# %% [markdown]
# CSV 2 - Student Feedback DAP CS 1201 - Student Feedback DAP CS 1201

# %%
data2 = pd.read_csv('CSV\Student Feedback DAP CS 1201.csv')

# %%
print(data2.head(10))
# Out:
#            USN  rural/ urban area  \
# 0  1RVU23CSE510             Urban
# 1  1RVU23CSE074             Urban
# 2  1RVU23CSE281             Urban
# 3  1RVU23CSE517             Rural
# 4  1RVU23CSE045             Urban
# 5  1RVU23CSE023             Urban
# 6  1RVU23CSE312             Urban
# 7  1RVU23CSE439             Urban
# 8  1RVU23CSE105             Urban
# 9  1RVU23USN474             Urban
#
#        Which teaching methods helped your learning?   \
# 0  Class discussions, including online discussion...
# 1  In-class learning activities, other than discu...
# 2  Class discussions, including online discussion...
# 3  Lectures, including online lectures;In-class c...
# 4  Class discussions, including online discussion...
# 5  Class discussions, including online discussion...
# 6  Class discussions, including online discussion...
# 7  Class discussions, including online discussion...
# 8  Class discussions, including online discussion...
# 9  Lectures, including online lectures;Class disc...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
# 5                                                NaN
# 6                                                Yes
# 7                                                 No
# 8                                                Yes
# 9                                                Yes
#
#   How much time did you spend weekly on this course outside of class for C01?\n  \
# 0                                                 R3
# 1                                                 R2
# 2                                                NaN
# 3                                                 T3
# 4                                                 T2
# 5                                                 T1
# 6                                                 T2
# 7                                                 T1
# 8                                                 T1
# 9                                                 T2
#
#   How much time did you spend weekly on this course outside of class for C02?   \
# 0                                                 R3
# 1                                                 R2
# 2                                                NaN
# 3                                                 T3
# 4                                                 T2
# 5                                                 T3
# 6                                                 T2
# 7                                                 T1
# 8                                                 T1
# 9                                                 T2
#
#   How much time did you spend weekly on this course outside of class for C03?   \
# 0                                                 R4
# 1                                                 R3
# 2                                                NaN
# 3                                                 T3
# 4                                                 T2
# 5                                                 T2
# 6                                                 T3
# 7                                                 T2
# 8                                                 T2
# 9                                                 T2
#
#   How much time did you spend weekly on this course outside of class for C04?   \
# 0                                                 R5
# 1                                                 R3
# 2                                                NaN
# 3                                                 T3
# 4                                                 T3
# 5                                                 T3
# 6                                                 T3
# 7                                                 T1
# 8                                                 T2
# 9                                                 T2
#
#   What level have you achieved in the course outcomes for C01?  \
# 0                                                 R7
# 1                                                 R6
# 2                                                 R4
# 3                                                 R7
# 4                                                 R4
# 5                                                 R6
# 6                                                 R5
# 7                                                 R4
# 8                                                 R5
# 9                                                 R6
#
#   What level have you achieved in the course outcomes for C02?  ...  \
# 0                                                 R5            ...
# 1                                                 R6            ...
# 2                                                 R4            ...
# 3                                                 R7            ...
# 4                                                 R4            ...
# 5                                                 R5            ...
# 6                                                 R4            ...
# 7                                                 R4            ...
# 8                                                 R6            ...
# 9                                                 R6            ...
#
#   Would more faculty concern improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
# 6                                                 NO
# 7                                                Yes
# 8                                                Yes
# 9                                                Yes
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
# 6                                                Yes
# 7                                                Yes
# 8                                                Yes
# 9                                                Yes
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
# 6                                                Yes
# 7                                                Yes
# 8                                                Yes
# 9                                                Yes
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
# 6                                                Yes
# 7                                                Yes
# 8                                                Yes
# 9                                                Yes
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
# 5                                                 NO
# 6                                                 NO
# 7                                                Yes
# 8                                                 NO
# 9                                                Yes
#
#   Would more outside help improve your learning in C01?.1  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
# 5                                                 NO
# 6                                                 NO
# 7                                                Yes
# 8                                                Yes
# 9                                                Yes
#
#   Would more outside help improve your learning in C01?.2  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
# 5                                                 NO
# 6                                                 NO
# 7                                                Yes
# 8                                                 NO
# 9                                                Yes
#
#   Would more outside help improve your learning in C01?.3  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
# 5                                                 NO
# 6                                                 NO
# 7                                                Yes
# 8                                                 NO
# 9                                                Yes
#
#   Your overall feedback about the course  \
# 0                        Good (70 - 90%)
# 1                      Excellent (> 90%)
# 2                      Excellent (> 90%)
# 3                        Good (70 - 90%)
# 4                        Good (70 - 90%)
# 5                        Good (70 - 90%)
# 6                      Excellent (> 90%)
# 7                        Okay (40 - 70%)
# 8                      Excellent (> 90%)
# 9                        Good (70 - 90%)
#
#      Write a paragraph about your course experience.
# 0   It helped me analyze graphs in more deeper level
# 1  Data Analysis with Python was a very useful co...
# 2                                          Excellent
# 3  It was a nice experience for me to analyse dat...
# 4                                                NaN
# 5  My experience was good and i liked this course...
# 6  It is an excellent course and has given me an ...
# 7  It was good but as I am new to this course it ...
# 8           It was good ,interactive and enjoyable.
# 9                                        It was good
#
# [10 rows x 42 columns]

# %%
print(data2.columns)
# Out:
# Index(['USN ', 'rural/ urban area',
#        'Which teaching methods helped your learning? ',
#        'Were you prepared to take this course based on prior coursework?',
#        'How much time did you spend weekly on this course outside of class for C01?\n',
#        'How much time did you spend weekly on this course outside of class for C02? ',
#        'How much time did you spend weekly on this course outside of class for C03? ',
#        'How much time did you spend weekly on this course outside of class for C04? ',
#        'What level have you achieved in the course outcomes for C01?',
#        'What level have you achieved in the course outcomes for C02?',
#        'What level have you achieved in the course outcomes for C03?',
#        'What level have you achieved in the course outcomes for C04?',
#        'What were the key aspects of your efforts in CO1?',
#        'What were the key aspects of your efforts in CO2?',
#        'What were the key aspects of your efforts in CO3?',
#        'What were the key aspects of your efforts in CO4?',
#        '\nHow satisfied are you with C01?',
#        '\nHow satisfied are you with C02?',
#        '\nHow satisfied are you with C03?',
#        '\nHow satisfied are you with C04?',
#        'List strategies for learning the course outcomes for C01',
#        'List strategies for learning the course outcomes for C02',
#        'List strategies for learning the course outcomes for C03',
#        'List strategies for learning the course outcomes for C04',
#        'How many marks will you give yourself for C01? \n',
#        'How many marks will you give yourself for C02? \n',
#        'How many marks will you give yourself for C03?',
#        'How many marks will you give yourself for C04?',
#        'If your marks are low in C01, who do you blame for your performance?',
#        'If your marks are low in C02, who do you blame for your performance?',
#        'If your marks are low in C03, who do you blame for your performance?',
#        'If your marks are low in C04, who do you blame for your performance?',
#        'Would more faculty concern improve your learning in C01?',
#        'Would more faculty concern improve your learning in C02?',
#        'Would more faculty concern improve your learning in C03?',
#        'Would more faculty concern improve your learning in C04?',
#        'Would more outside help improve your learning in C01?',
#        'Would more outside help improve your learning in C01?.1',
#        'Would more outside help improve your learning in C01?.2',
#        'Would more outside help improve your learning in C01?.3',
#        'Your overall feedback about the course',
#        'Write a paragraph about your course experience.'],
#       dtype='object')

# %%
# Print the DataFrame info, which includes column names and data types
print(data2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 42 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   USN                                                                           204 non-null    object
#  1   rural/ urban area                                                             204 non-null    object
#  2   Which teaching methods helped your learning?                                  201 non-null    object
#  3   Were you prepared to take this course based on prior coursework?              196 non-null    object
#  4   How much time did you spend weekly on this course outside of class for C01?
#   201 non-null    object
#  5   How much time did you spend weekly on this course outside of class for C02?   200 non-null    object
#  6   How much time did you spend weekly on this course outside of class for C03?   200 non-null    object
#  7   How much time did you spend weekly on this course outside of class for C04?   199 non-null    object
#  8   What level have you achieved in the course outcomes for C01?                  204 non-null    object
#  9   What level have you achieved in the course outcomes for C02?                  204 non-null    object
#  10  What level have you achieved in the course outcomes for C03?                  204 non-null    object
#  11  What level have you achieved in the course outcomes for C04?                  204 non-null    object
#  12  What were the key aspects of your efforts in CO1?                             192 non-null    object
#  13  What were the key aspects of your efforts in CO2?                             191 non-null    object
#  14  What were the key aspects of your efforts in CO3?                             190 non-null    object
#  15  What were the key aspects of your efforts in CO4?                             190 non-null    object
#  16
# How satisfied are you with C01?                                              204 non-null    object
#  17
# How satisfied are you with C02?                                              204 non-null    object
#  18
# How satisfied are you with C03?                                              204 non-null    object
#  19
# How satisfied are you with C04?                                              204 non-null    object
#  20  List strategies for learning the course outcomes for C01                      204 non-null    object
#  21  List strategies for learning the course outcomes for C02                      204 non-null    object
#  22  List strategies for learning the course outcomes for C03                      204 non-null    object
#  23  List strategies for learning the course outcomes for C04                      204 non-null    object
#  24  How many marks will you give yourself for C01?
#                               204 non-null    int64
#  25  How many marks will you give yourself for C02?
#                               204 non-null    int64
#  26  How many marks will you give yourself for C03?                                204 non-null    int64
#  27  How many marks will you give yourself for C04?                                204 non-null    int64
#  28  If your marks are low in C01, who do you blame for your performance?          204 non-null    object
#  29  If your marks are low in C02, who do you blame for your performance?          204 non-null    object
#  30  If your marks are low in C03, who do you blame for your performance?          204 non-null    object
#  31  If your marks are low in C04, who do you blame for your performance?          204 non-null    object
#  32  Would more faculty concern improve your learning in C01?                      204 non-null    object
#  33  Would more faculty concern improve your learning in C02?                      204 non-null    object
#  34  Would more faculty concern improve your learning in C03?                      204 non-null    object
#  35  Would more faculty concern improve your learning in C04?                      204 non-null    object
#  36  Would more outside help improve your learning in C01?                         204 non-null    object
#  37  Would more outside help improve your learning in C01?.1                       204 non-null    object
#  38  Would more outside help improve your learning in C01?.2                       204 non-null    object
#  39  Would more outside help improve your learning in C01?.3                       204 non-null    object
#  40  Your overall feedback about the course                                        204 non-null    object
#  41  Write a paragraph about your course experience.                               200 non-null    object
# dtypes: int64(4), object(38)
# memory usage: 67.1+ KB
# None

# %%
# Strip whitespace and newline characters from all column names
data2.columns = data2.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping2 = {
    'R1': 'Less than one hour',
    'R2': '1-2 hours',
    'T2': '1-2 hours',
    'R3': '3-4 hours',
    'T3': '3-4 hours',
    'R4': '5-6 hours',
    'R5': '7-8 hours',
    'R6': '9-10 hours',
    'R7': '11-12 hours',
    'R8': '13-15 hours',
    'R9': 'More than 15 hours'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify2 = [
    'How much time did you spend weekly on this course outside of class for C01?',
    'How much time did you spend weekly on this course outside of class for C02?',
    'How much time did you spend weekly on this course outside of class for C03?',
    'How much time did you spend weekly on this course outside of class for C04?'
]

# Replace the values in the specified columns
for column in columns_to_modify2:
    if column in data2.columns:
        data2[column] = data2[column].replace(value_mapping2)

# %%
print(data2[columns_to_modify2].head())
# Out:
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          3-4 hours
# 1                                          1-2 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C02?  \
# 0                                          3-4 hours
# 1                                          1-2 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C03?  \
# 0                                          5-6 hours
# 1                                          3-4 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C04?
# 0                                          7-8 hours
# 1                                          3-4 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          3-4 hours

# %%
print(data2.columns)
# Out:
# Index(['USN', 'rural/ urban area',
#        'Which teaching methods helped your learning?',
#        'Were you prepared to take this course based on prior coursework?',
#        'How much time did you spend weekly on this course outside of class for C01?',
#        'How much time did you spend weekly on this course outside of class for C02?',
#        'How much time did you spend weekly on this course outside of class for C03?',
#        'How much time did you spend weekly on this course outside of class for C04?',
#        'What level have you achieved in the course outcomes for C01?',
#        'What level have you achieved in the course outcomes for C02?',
#        'What level have you achieved in the course outcomes for C03?',
#        'What level have you achieved in the course outcomes for C04?',
#        'What were the key aspects of your efforts in CO1?',
#        'What were the key aspects of your efforts in CO2?',
#        'What were the key aspects of your efforts in CO3?',
#        'What were the key aspects of your efforts in CO4?',
#        'How satisfied are you with C01?', 'How satisfied are you with C02?',
#        'How satisfied are you with C03?', 'How satisfied are you with C04?',
#        'List strategies for learning the course outcomes for C01',
#        'List strategies for learning the course outcomes for C02',
#        'List strategies for learning the course outcomes for C03',
#        'List strategies for learning the course outcomes for C04',
#        'How many marks will you give yourself for C01?',
#        'How many marks will you give yourself for C02?',
#        'How many marks will you give yourself for C03?',
#        'How many marks will you give yourself for C04?',
#        'If your marks are low in C01, who do you blame for your performance?',
#        'If your marks are low in C02, who do you blame for your performance?',
#        'If your marks are low in C03, who do you blame for your performance?',
#        'If your marks are low in C04, who do you blame for your performance?',
#        'Would more faculty concern improve your learning in C01?',
#        'Would more faculty concern improve your learning in C02?',
#        'Would more faculty concern improve your learning in C03?',
#        'Would more faculty concern improve your learning in C04?',
#        'Would more outside help improve your learning in C01?',
#        'Would more outside help improve your learning in C01?.1',
#        'Would more outside help improve your learning in C01?.2',
#        'Would more outside help improve your learning in C01?.3',
#        'Your overall feedback about the course',
#        'Write a paragraph about your course experience.'],
#       dtype='object')

# %%
# Strip whitespace and newline characters from all column names
data2.columns = data2.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping2 = {
    'R1': 'Memorizing facts and repeating ideas from the readings and lectures',
    'R2': 'Applying basic elements of an idea, experience, or theory',
    'R3': 'Synthesizing and organizing ideas, information, or experiences',
    'R4': 'Making judgments about the value of information, arguments, or methods',
    'R5': 'Applying theories or concepts to practical problems or in new situations',
    'R6': 'Solving problems',
    'R7': 'Thinking creatively or critically',
    'R8': 'Teamwork or group activities',
    'R9': 'Reading for deep understanding',
    'R10': 'Presenting in person or via a recording',
    'R8': 'Doing lab work',
    'R9': 'Writing'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify2 = [
     'What level have you achieved in the course outcomes for C01?',
       'What level have you achieved in the course outcomes for C02?',
       'What level have you achieved in the course outcomes for C03?',
       'What level have you achieved in the course outcomes for C04?'
]

# Replace the values in the specified columns
for column in columns_to_modify2:
    if column in data2.columns:
        data2[column] = data2[column].replace(value_mapping2)

# %%
# Print the modified columns to verify the changes
print(data2[columns_to_modify2].head())
# Out:
#   What level have you achieved in the course outcomes for C01?  \
# 0                  Thinking creatively or critically
# 1                                   Solving problems
# 2  Making judgments about the value of informatio...
# 3                  Thinking creatively or critically
# 4  Making judgments about the value of informatio...
#
#   What level have you achieved in the course outcomes for C02?  \
# 0  Applying theories or concepts to practical pro...
# 1                                   Solving problems
# 2  Making judgments about the value of informatio...
# 3                  Thinking creatively or critically
# 4  Making judgments about the value of informatio...
#
#   What level have you achieved in the course outcomes for C03?  \
# 0  Applying theories or concepts to practical pro...
# 1  Applying theories or concepts to practical pro...
# 2  Making judgments about the value of informatio...
# 3                                   Solving problems
# 4  Making judgments about the value of informatio...
#
#   What level have you achieved in the course outcomes for C04?
# 0  Applying theories or concepts to practical pro...
# 1  Applying theories or concepts to practical pro...
# 2  Synthesizing and organizing ideas, information...
# 3                                   Solving problems
# 4  Making judgments about the value of informatio...

# %%
# Strip whitespace and newline characters from all column names (if not already done)
data2.columns = data2.columns.str.strip()

# Define the columns to delete
columns_to_delete2 = [
    'What were the key aspects of your efforts in CO1?',
    'What were the key aspects of your efforts in CO2?',
    'What were the key aspects of your efforts in CO3?',
    'What were the key aspects of your efforts in CO4?'
]

# Drop the columns from the DataFrame
data2 = data2.drop(columns=columns_to_delete)

# Print the DataFrame to verify the columns are deleted
print(data2.head())
# Out:
#             USN rural/ urban area  \
# 0  1RVU23CSE510             Urban
# 1  1RVU23CSE074             Urban
# 2  1RVU23CSE281             Urban
# 3  1RVU23CSE517             Rural
# 4  1RVU23CSE045             Urban
#
#         Which teaching methods helped your learning?  \
# 0  Class discussions, including online discussion...
# 1  In-class learning activities, other than discu...
# 2  Class discussions, including online discussion...
# 3  Lectures, including online lectures;In-class c...
# 4  Class discussions, including online discussion...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          3-4 hours
# 1                                          1-2 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C02?  \
# 0                                          3-4 hours
# 1                                          1-2 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C03?  \
# 0                                          5-6 hours
# 1                                          3-4 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C04?  \
# 0                                          7-8 hours
# 1                                          3-4 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          3-4 hours
#
#   What level have you achieved in the course outcomes for C01?  \
# 0                  Thinking creatively or critically
# 1                                   Solving problems
# 2  Making judgments about the value of informatio...
# 3                  Thinking creatively or critically
# 4  Making judgments about the value of informatio...
#
#   What level have you achieved in the course outcomes for C02?  ...  \
# 0  Applying theories or concepts to practical pro...            ...
# 1                                   Solving problems            ...
# 2  Making judgments about the value of informatio...            ...
# 3                  Thinking creatively or critically            ...
# 4  Making judgments about the value of informatio...            ...
#
#   Would more faculty concern improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
#
#   Would more outside help improve your learning in C01?.1  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
#
#   Would more outside help improve your learning in C01?.2  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
#
#   Would more outside help improve your learning in C01?.3  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
#
#   Your overall feedback about the course  \
# 0                        Good (70 - 90%)
# 1                      Excellent (> 90%)
# 2                      Excellent (> 90%)
# 3                        Good (70 - 90%)
# 4                        Good (70 - 90%)
#
#      Write a paragraph about your course experience.
# 0   It helped me analyze graphs in more deeper level
# 1  Data Analysis with Python was a very useful co...
# 2                                          Excellent
# 3  It was a nice experience for me to analyse dat...
# 4                                                NaN
#
# [5 rows x 38 columns]

# %%
# Strip whitespace and newline characters from all column names
data2.columns = data2.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping2 = {
    'R1': 'Happy as I put in the required effort',
    'R2': 'Happy as I understood the teacher',
    'R3': 'Happy as I enjoyed doing the CO activities',
    'R4': 'Neutral with my effort',
    'R5': 'Neutral about understanding the teacher',
    'R6': 'Neutral about the activities',
    'R7': 'Not happy as I did not put in the required effort',
    'R8': 'Not happy as I could not understand the teacher',
    'R9': 'Not happy as the CO activities were boring' 
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify2 = [
     'How satisfied are you with C01?', 'How satisfied are you with C02?',
       'How satisfied are you with C03?', 'How satisfied are you with C04?'
]

# Replace the values in the specified columns
for column in columns_to_modify2:
    if column in data2.columns:
        data2[column] = data2[column].replace(value_mapping2)

# %%
# Print the modified columns to verify the changes
print(data2[columns_to_modify2].head())
# Out:
#                      How satisfied are you with C01?  \
# 0         Happy as I enjoyed doing the CO activities
# 1                             Neutral with my effort
# 2  Not happy as I did not put in the required effort
# 3              Happy as I put in the required effort
# 4         Happy as I enjoyed doing the CO activities
#
#               How satisfied are you with C02?  \
# 0  Happy as I enjoyed doing the CO activities
# 1                      Neutral with my effort
# 2           Happy as I understood the teacher
# 3       Happy as I put in the required effort
# 4  Happy as I enjoyed doing the CO activities
#
#               How satisfied are you with C03?  \
# 0  Happy as I enjoyed doing the CO activities
# 1                      Neutral with my effort
# 2           Happy as I understood the teacher
# 3  Happy as I enjoyed doing the CO activities
# 4  Happy as I enjoyed doing the CO activities
#
#               How satisfied are you with C04?
# 0  Happy as I enjoyed doing the CO activities
# 1                      Neutral with my effort
# 2       Happy as I put in the required effort
# 3  Happy as I enjoyed doing the CO activities
# 4  Happy as I enjoyed doing the CO activities

# %%
 # Strip whitespace and newline characters from all column names
data2.columns = data2.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping2 = {
    'R1': 'Copy-paste friends work',
    'R2': 'Copy-paste from online',
    'R3': 'Understand others work but redo it, referring to it',
    'R4': 'Understand others work but redo it, without referring to it',
    'R5': 'Try by myself and get it reviewed by peers/teaching assistants/teachers'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify2 = [
     'List strategies for learning the course outcomes for C01',
       'List strategies for learning the course outcomes for C02',
       'List strategies for learning the course outcomes for C03',
       'List strategies for learning the course outcomes for C04'
]

# Replace the values in the specified columns
for column in columns_to_modify2:
    if column in data2.columns:
        data2[column] = data2[column].replace(value_mapping2)

# %%
# Print the modified columns to verify the changes
print(data2[columns_to_modify2].head())
# Out:
#   List strategies for learning the course outcomes for C01  \
# 0  Try by myself and get it reviewed by peers/tea...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, referring ...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Understand others work but redo it, referring ...
#
#   List strategies for learning the course outcomes for C02  \
# 0  Understand others work but redo it, without re...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Try by myself and get it reviewed by peers/tea...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Understand others work but redo it, referring ...
#
#   List strategies for learning the course outcomes for C03  \
# 0  Understand others work but redo it, without re...
# 1  Understand others work but redo it, without re...
# 2  Understand others work but redo it, referring ...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Understand others work but redo it, referring ...
#
#   List strategies for learning the course outcomes for C04
# 0  Understand others work but redo it, without re...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, referring ...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Understand others work but redo it, referring ...

# %%
 # Strip whitespace and newline characters from all column names
data2.columns = data2.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping2 = {
    'R1': 'Copy-paste friends work',
    'R2': 'Copy-paste from online',
    'R3': 'Understand others work but redo it, referring to it',
    'R4': 'Understand others work but redo it, without referring to it',
    'R5': 'Try by myself and get it reviewed by peers/teaching assistants/teachers'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify2 = [
     'List strategies for learning the course outcomes for C01',
       'List strategies for learning the course outcomes for C02',
       'List strategies for learning the course outcomes for C03',
       'List strategies for learning the course outcomes for C04'
]

# Replace the values in the specified columns
for column2 in columns_to_modify2:
    if column in data2.columns:
        data2[column] = data2[column].replace(value_mapping2)

# %%
# Print the modified columns to verify the changes
print(data2[columns_to_modify].head())
# Out:
#   List strategies for learning the course outcomes for C01  \
# 0  Try by myself and get it reviewed by peers/tea...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, referring ...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Understand others work but redo it, referring ...
#
#   List strategies for learning the course outcomes for C02  \
# 0  Understand others work but redo it, without re...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Try by myself and get it reviewed by peers/tea...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Understand others work but redo it, referring ...
#
#   List strategies for learning the course outcomes for C03  \
# 0  Understand others work but redo it, without re...
# 1  Understand others work but redo it, without re...
# 2  Understand others work but redo it, referring ...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Understand others work but redo it, referring ...
#
#   List strategies for learning the course outcomes for C04
# 0  Understand others work but redo it, without re...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, referring ...
# 3  Try by myself and get it reviewed by peers/tea...
# 4  Understand others work but redo it, referring ...

# %%
 # Strip whitespace and newline characters from all column names
data2.columns = data2.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping = {
    'R1': 'Copy-paste friends work',
    'R2': 'Copy-paste from online',
    'R3': 'Understand others work but redo it, referring to it',
    'R4': 'Understand others work but redo it, without referring to it',
    'R5': 'Try by myself and get it reviewed by peers/teaching assistants/teachers'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify = [
     'List strategies for learning the course outcomes for C01',
       'List strategies for learning the course outcomes for C02',
       'List strategies for learning the course outcomes for C03',
       'List strategies for learning the course outcomes for C04'
]

# Replace the values in the specified columns
for column in columns_to_modify:
    if column in data2.columns:
        data2[column] = data2[column].replace(value_mapping)

# %%
data.head()
# Out:
#             USN  Gender  Age 12th marks % rural/ urban area Section  \
# 0  1RVU23BSC147    Male   18           75             Urban   IDA_C
# 1  1RVUBSC23016  Female   23           74             Urban   IDA_B
# 2  1RVU23BSC073    Male   20           65             Rural   IDA_A
# 3           140  Female   20           72             Urban   IDA_B
# 4  1RVU23BSC001    Male   18         70.4             Urban   IDA_B
#
#                                Why take this course?  \
# 0  Fulfills general curriculum/education requirem...
# 1  Fulfills general curriculum/education requirem...
# 2  Fulfills general curriculum/education requirem...
# 3  Fulfills general curriculum/education requirem...
# 4                            Interest in the subject
#
#         Which teaching methods helped your learning?  \
# 0  Lectures, including online lectures;Class disc...
# 1  Lectures, including online lectures;Class disc...
# 2  Lectures, including online lectures;Class disc...
# 3  Lectures, including online lectures;Class disc...
# 4  Lectures, including online lectures;Class disc...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          3-4 hours
# 1                                          5-6 hours
# 2                                          7-8 hours
# 3                                          1-2 hours
# 4                                          1-2 hours
#
#    ... Explain briefly your rationale for you choice to the previous question  \
# 0  ...  As I enjoyed learning this subject and I learn...
# 1  ...  For any student themselves or the way of teach...
# 2  ...  I will blame myself beacuse the teachers gave ...
# 3  ...                                                Nil
# 4  ...  Understood the subject due to practice and the...
#
#   Would more faculty concern improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C04? Your overall feedback
# 0                                                 NO        Excellent (> 90%)
# 1                                                Yes          Good (70 - 90%)
# 2                                                Yes        Excellent (> 90%)
# 3                                                 NO        Excellent (> 90%)
# 4                                                 NO        Excellent (> 90%)
#
# [5 rows x 43 columns]

# %% [markdown]
# CSV 3 - Student Feedback DAP CS 1203 - Student Feedback DAP CS 1203

# %%
data3 = pd.read_csv('CSV\Student Feedback form_IDA2_CS1203.csv')

# %%
print(data3.head(10))
# Out:
#             USN   Gender  Age 12th marks % rural/ urban area  Section  \
# 0   1RVUBSC23016  Female   23           74              Urban   IDA_B
# 1   1RVU23BSC061    Male   19          83%              Urban   IDA_B
# 2   1RVU23BSC073    Male   20           65              Rural   IDA_A
# 3   1RVU23BSC157  Female   18          88%              Urban   IDA_B
# 4  1RVU23BSC088   Female   18       93.33%              Urban   IDA_C
# 5   1RVU23BSC001    Male   18         70.4              Urban   IDA_B
# 6   1RVU23BSC059    Male   19           71              Rural   IDA_A
# 7   1RVU23BSC134    Male   18          78%              Urban   IDA_C
# 8   1RVU23BSC122  Female   19           70              Rural   IDA_C
# 9   1RVU23BSC147    Male   18           75              Urban   IDA_C
#
#                                Why take this course?  \
# 0  Fulfills general curriculum/education requirem...
# 1  Required (Core) for Program, Minor, or Special...
# 2  Fulfills general curriculum/education requirem...
# 3                            Interest in the subject
# 4  Fulfills general curriculum/education requirem...
# 5                            Interest in the subject
# 6  Fulfills general curriculum/education requirem...
# 7  Fulfills general curriculum/education requirem...
# 8  Fulfills general curriculum/education requirem...
# 9  Fulfills general curriculum/education requirem...
#
#        Which teaching methods helped your learning?   \
# 0  Lectures, including online lectures;Class disc...
# 1  Lectures, including online lectures;Class disc...
# 2  Lectures, including online lectures;Class disc...
# 3  Lectures, including online lectures;Teamwork o...
# 4  Lectures, including online lectures;Class disc...
# 5  Lectures, including online lectures;Class disc...
# 6  Lectures, including online lectures;Class disc...
# 7  Lectures, including online lectures;Class disc...
# 8  Lectures, including online lectures;Class disc...
# 9  Lectures, including online lectures;Class disc...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
# 5                                                Yes
# 6                                                 No
# 7                                                 No
# 8                                                Yes
# 9                                                Yes
#
#   How much time did you spend weekly on this course outside of class for C01?\n  \
# 0                                                 R4
# 1                                                 R6
# 2                                                 R5
# 3                                                 R1
# 4                                                 R1
# 5                                                 R2
# 6                                                 R2
# 7                                                 R2
# 8                                                 R2
# 9                                                 R4
#
#    ... Would more faculty concern improve your learning in C01?  \
# 0  ...                                                 NO
# 1  ...                                                 NO
# 2  ...                                                Yes
# 3  ...                                                 NO
# 4  ...                                                Yes
# 5  ...                                                 NO
# 6  ...                                                Yes
# 7  ...                                                Yes
# 8  ...                                                 NO
# 9  ...                                                 NO
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
# 5                                                 NO
# 6                                                Yes
# 7                                                Yes
# 8                                                 NO
# 9                                                 NO
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
# 5                                                 NO
# 6                                                Yes
# 7                                                Yes
# 8                                                 NO
# 9                                                 NO
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                Yes
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
# 5                                                 NO
# 6                                                Yes
# 7                                                Yes
# 8                                                 NO
# 9                                                 NO
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
# 5                                                 NO
# 6                                                Yes
# 7                                                Yes
# 8                                                 NO
# 9                                                 NO
#
#   Would more outside help improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
# 5                                                 NO
# 6                                                Yes
# 7                                                Yes
# 8                                                 NO
# 9                                                 NO
#
#   Would more outside help improve your learning in C03?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
# 5                                                 NO
# 6                                                Yes
# 7                                                Yes
# 8                                                 NO
# 9                                                 NO
#
#   Would more outside help improve your learning in C04?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
# 5                                                 NO
# 6                                                Yes
# 7                                                Yes
# 8                                                 NO
# 9                                                 NO
#
#   Your overall feedback about the course  \
# 0                        Good (70 - 90%)
# 1                      Excellent (> 90%)
# 2                      Excellent (> 90%)
# 3                        Good (70 - 90%)
# 4                      Excellent (> 90%)
# 5                      Excellent (> 90%)
# 6                      Excellent (> 90%)
# 7                      Excellent (> 90%)
# 8                      Excellent (> 90%)
# 9                      Excellent (> 90%)
#
#      Write a paragraph about your course experience.
# 0  It was different but go to learn to analyze th...
# 1                                       It was nice.
# 2                                               Good
# 3  this course was very intersesting to learn . a...
# 4  Overall feedback about the course is good and ...
# 5  Favourite course in the semester. Had interest...
# 6  I enjoyed the course throughout and learnt a l...
# 7
# 8  I am happy with the outcome i have got and kno...
# 9                                  It was excellent
#
# [10 rows x 49 columns]

# %%
print(data3.columns)
# Out:
# Index(['USN ', 'Gender', 'Age', '12th marks %', 'rural/ urban area ',
#        'Section', 'Why take this course?',
#        'Which teaching methods helped your learning? ',
#        'Were you prepared to take this course based on prior coursework?',
#        'How much time did you spend weekly on this course outside of class for C01?\n',
#        'How much time did you spend weekly on this course outside of class for C02? ',
#        'How much time did you spend weekly on this course outside of class for C03? ',
#        'How much time did you spend weekly on this course outside of class for C04? ',
#        'What level have you achieved in the course outcomes for C01?',
#        'What level have you achieved in the course outcomes for C02?',
#        'What level have you achieved in the course outcomes for C03?',
#        'What level have you achieved in the course outcomes for C04?',
#        'What were the key aspects of your efforts in CO1?',
#        'What were the key aspects of your efforts in CO2?',
#        'What were the key aspects of your efforts in CO3?',
#        'What were the key aspects of your efforts in CO4?',
#        '\nHow satisfied are you with C01?',
#        '\nHow satisfied are you with C02?',
#        '\nHow satisfied are you with C03?',
#        '\nHow satisfied are you with C04?',
#        'List strategies for learning the course outcomes for C01',
#        'List strategies for learning the course outcomes for C02',
#        'List strategies for learning the course outcomes for C03',
#        'List strategies for learning the course outcomes for C04',
#        'How many marks will you give yourself for C01? \n',
#        'How many marks will you give yourself for C02? \n',
#        'How many marks will you give yourself for C03? \n',
#        'How many marks will you give yourself for C04? \n',
#        'If your marks are low in C01, who do you blame for your performance?',
#        'If your marks are low in C02, who do you blame for your performance?',
#        'If your marks are low in C03, who do you blame for your performance?',
#        'If your marks are low in C04, who do you blame for your performance?',
#        'Explain briefly your rationale for you choice to the previous question',
#        'Were class activities allowed to be submitted after the class timing? [CO1]',
#        'Would more faculty concern improve your learning in C01?',
#        'Would more faculty concern improve your learning in C02?',
#        'Would more faculty concern improve your learning in C03?',
#        'Would more faculty concern improve your learning in C04?',
#        'Would more outside help improve your learning in C01?',
#        'Would more outside help improve your learning in C02?',
#        'Would more outside help improve your learning in C03?',
#        'Would more outside help improve your learning in C04?',
#        'Your overall feedback about the course',
#        'Write a paragraph about your course experience.'],
#       dtype='object')

# %%
# Print the DataFrame info, which includes column names and data types
print(data3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 49 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   USN                                                                           141 non-null    object
#  1   Gender                                                                        141 non-null    object
#  2   Age                                                                           141 non-null    int64
#  3   12th marks %                                                                  141 non-null    object
#  4   rural/ urban area                                                             141 non-null    object
#  5   Section                                                                       141 non-null    object
#  6   Why take this course?                                                         141 non-null    object
#  7   Which teaching methods helped your learning?                                  141 non-null    object
#  8   Were you prepared to take this course based on prior coursework?              141 non-null    object
#  9   How much time did you spend weekly on this course outside of class for C01?
#   140 non-null    object
#  10  How much time did you spend weekly on this course outside of class for C02?   140 non-null    object
#  11  How much time did you spend weekly on this course outside of class for C03?   140 non-null    object
#  12  How much time did you spend weekly on this course outside of class for C04?   141 non-null    object
#  13  What level have you achieved in the course outcomes for C01?                  141 non-null    object
#  14  What level have you achieved in the course outcomes for C02?                  141 non-null    object
#  15  What level have you achieved in the course outcomes for C03?                  141 non-null    object
#  16  What level have you achieved in the course outcomes for C04?                  141 non-null    object
#  17  What were the key aspects of your efforts in CO1?                             141 non-null    object
#  18  What were the key aspects of your efforts in CO2?                             140 non-null    object
#  19  What were the key aspects of your efforts in CO3?                             140 non-null    object
#  20  What were the key aspects of your efforts in CO4?                             139 non-null    object
#  21
# How satisfied are you with C01?                                              141 non-null    object
#  22
# How satisfied are you with C02?                                              141 non-null    object
#  23
# How satisfied are you with C03?                                              141 non-null    object
#  24
# How satisfied are you with C04?                                              141 non-null    object
#  25  List strategies for learning the course outcomes for C01                      141 non-null    object
#  26  List strategies for learning the course outcomes for C02                      141 non-null    object
#  27  List strategies for learning the course outcomes for C03                      141 non-null    object
#  28  List strategies for learning the course outcomes for C04                      141 non-null    object
#  29  How many marks will you give yourself for C01?
#                               141 non-null    int64
#  30  How many marks will you give yourself for C02?
#                               141 non-null    int64
#  31  How many marks will you give yourself for C03?
#                               141 non-null    int64
#  32  How many marks will you give yourself for C04?
#                               141 non-null    int64
#  33  If your marks are low in C01, who do you blame for your performance?          141 non-null    object
#  34  If your marks are low in C02, who do you blame for your performance?          141 non-null    object
#  35  If your marks are low in C03, who do you blame for your performance?          141 non-null    object
#  36  If your marks are low in C04, who do you blame for your performance?          141 non-null    object
#  37  Explain briefly your rationale for you choice to the previous question        136 non-null    object
#  38  Were class activities allowed to be submitted after the class timing? [CO1]   141 non-null    object
#  39  Would more faculty concern improve your learning in C01?                      141 non-null    object
#  40  Would more faculty concern improve your learning in C02?                      141 non-null    object
#  41  Would more faculty concern improve your learning in C03?                      141 non-null    object
#  42  Would more faculty concern improve your learning in C04?                      141 non-null    object
#  43  Would more outside help improve your learning in C01?                         141 non-null    object
#  44  Would more outside help improve your learning in C02?                         141 non-null    object
#  45  Would more outside help improve your learning in C03?                         141 non-null    object
#  46  Would more outside help improve your learning in C04?                         141 non-null    object
#  47  Your overall feedback about the course                                        141 non-null    object
#  48  Write a paragraph about your course experience.                               141 non-null    object
# dtypes: int64(5), object(44)
# memory usage: 54.1+ KB
# None

# %%
# Strip whitespace and newline characters from all column names
data3.columns = data3.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping3 = {
    'R1': 'Less than one hour',
    'R2': '1-2 hours',
    'R3': '3-4 hours',
    'R4': '5-6 hours',
    'R5': '7-8 hours',
    'R6': '9-10 hours',
    'R7': '11-12 hours',
    'R8': '13-15 hours',
    'R9': 'More than 15 hours'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify3 = [
    'How much time did you spend weekly on this course outside of class for C01?',
    'How much time did you spend weekly on this course outside of class for C02?',
    'How much time did you spend weekly on this course outside of class for C03?',
    'How much time did you spend weekly on this course outside of class for C04?'
]

# Replace the values in the specified columns
for column in columns_to_modify3:
    if column in data3.columns:
        data3[column] = data3[column].replace(value_mapping3)

# %%
print(data3[columns_to_modify3].head())
# Out:
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          5-6 hours
# 1                                         9-10 hours
# 2                                          7-8 hours
# 3                                 Less than one hour
# 4                                 Less than one hour
#
#   How much time did you spend weekly on this course outside of class for C02?  \
# 0                                          5-6 hours
# 1                                         9-10 hours
# 2                                          7-8 hours
# 3                                          1-2 hours
# 4                                 Less than one hour
#
#   How much time did you spend weekly on this course outside of class for C03?  \
# 0                                          7-8 hours
# 1                                         9-10 hours
# 2                                          7-8 hours
# 3                                          1-2 hours
# 4                                 Less than one hour
#
#   How much time did you spend weekly on this course outside of class for C04?
# 0                                          7-8 hours
# 1                                         9-10 hours
# 2                                          7-8 hours
# 3                                          1-2 hours
# 4                                 Less than one hour

# %%
print(data3.columns)
# Out:
# Index(['USN', 'Gender', 'Age', '12th marks %', 'rural/ urban area', 'Section',
#        'Why take this course?', 'Which teaching methods helped your learning?',
#        'Were you prepared to take this course based on prior coursework?',
#        'How much time did you spend weekly on this course outside of class for C01?',
#        'How much time did you spend weekly on this course outside of class for C02?',
#        'How much time did you spend weekly on this course outside of class for C03?',
#        'How much time did you spend weekly on this course outside of class for C04?',
#        'What level have you achieved in the course outcomes for C01?',
#        'What level have you achieved in the course outcomes for C02?',
#        'What level have you achieved in the course outcomes for C03?',
#        'What level have you achieved in the course outcomes for C04?',
#        'What were the key aspects of your efforts in CO1?',
#        'What were the key aspects of your efforts in CO2?',
#        'What were the key aspects of your efforts in CO3?',
#        'What were the key aspects of your efforts in CO4?',
#        'How satisfied are you with C01?', 'How satisfied are you with C02?',
#        'How satisfied are you with C03?', 'How satisfied are you with C04?',
#        'List strategies for learning the course outcomes for C01',
#        'List strategies for learning the course outcomes for C02',
#        'List strategies for learning the course outcomes for C03',
#        'List strategies for learning the course outcomes for C04',
#        'How many marks will you give yourself for C01?',
#        'How many marks will you give yourself for C02?',
#        'How many marks will you give yourself for C03?',
#        'How many marks will you give yourself for C04?',
#        'If your marks are low in C01, who do you blame for your performance?',
#        'If your marks are low in C02, who do you blame for your performance?',
#        'If your marks are low in C03, who do you blame for your performance?',
#        'If your marks are low in C04, who do you blame for your performance?',
#        'Explain briefly your rationale for you choice to the previous question',
#        'Were class activities allowed to be submitted after the class timing? [CO1]',
#        'Would more faculty concern improve your learning in C01?',
#        'Would more faculty concern improve your learning in C02?',
#        'Would more faculty concern improve your learning in C03?',
#        'Would more faculty concern improve your learning in C04?',
#        'Would more outside help improve your learning in C01?',
#        'Would more outside help improve your learning in C02?',
#        'Would more outside help improve your learning in C03?',
#        'Would more outside help improve your learning in C04?',
#        'Your overall feedback about the course',
#        'Write a paragraph about your course experience.'],
#       dtype='object')

# %%
# Strip whitespace and newline characters from all column names
data3.columns = data3.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping3 = {
    'R1': 'Memorizing facts and repeating ideas from the readings and lectures',
    'R2': 'Applying basic elements of an idea, experience, or theory',
    'R3': 'Synthesizing and organizing ideas, information, or experiences',
    'R4': 'Making judgments about the value of information, arguments, or methods',
    'R5': 'Applying theories or concepts to practical problems or in new situations',
    'R6': 'Solving problems',
    'R7': 'Thinking creatively or critically',
    'R8': 'Teamwork or group activities',
    'R9': 'Reading for deep understanding',
    'R10': 'Presenting in person or via a recording',
    'R8': 'Doing lab work',
    'R9': 'Writing'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify3 = [
     'What level have you achieved in the course outcomes for C01?',
       'What level have you achieved in the course outcomes for C02?',
       'What level have you achieved in the course outcomes for C03?',
       'What level have you achieved in the course outcomes for C04?'
]

# Replace the values in the specified columns
for column in columns_to_modify3:
    if column in data3.columns:
        data3[column] = data3[column].replace(value_mapping3)

# %%
# Print the modified columns to verify the changes
print(data3[columns_to_modify3].head())
# Out:
#   What level have you achieved in the course outcomes for C01?  \
# 0                                   Solving problems
# 1                  Thinking creatively or critically
# 2                                   Solving problems
# 3                                   Solving problems
# 4                                   Solving problems
#
#   What level have you achieved in the course outcomes for C02?  \
# 0                                   Solving problems
# 1                  Thinking creatively or critically
# 2                                   Solving problems
# 3                                   Solving problems
# 4                                   Solving problems
#
#   What level have you achieved in the course outcomes for C03?  \
# 0                                   Solving problems
# 1                  Thinking creatively or critically
# 2                                   Solving problems
# 3                                   Solving problems
# 4                                   Solving problems
#
#   What level have you achieved in the course outcomes for C04?
# 0                                   Solving problems
# 1                  Thinking creatively or critically
# 2                                   Solving problems
# 3  Applying theories or concepts to practical pro...
# 4                                   Solving problems

# %%
# Strip whitespace and newline characters from all column names (if not already done)
data3.columns = data3.columns.str.strip()

# Define the columns to delete
columns_to_delete3 = [
    'What were the key aspects of your efforts in CO1?',
    'What were the key aspects of your efforts in CO2?',
    'What were the key aspects of your efforts in CO3?',
    'What were the key aspects of your efforts in CO4?'
]

# Drop the columns from the DataFrame
data3 = data3.drop(columns=columns_to_delete3)

# Print the DataFrame to verify the columns are deleted
print(data3.head())
# Out:
#              USN  Gender  Age 12th marks % rural/ urban area Section  \
# 0   1RVUBSC23016  Female   23           74             Urban   IDA_B
# 1   1RVU23BSC061    Male   19          83%             Urban   IDA_B
# 2   1RVU23BSC073    Male   20           65             Rural   IDA_A
# 3   1RVU23BSC157  Female   18          88%             Urban   IDA_B
# 4  1RVU23BSC088   Female   18       93.33%             Urban   IDA_C
#
#                                Why take this course?  \
# 0  Fulfills general curriculum/education requirem...
# 1  Required (Core) for Program, Minor, or Special...
# 2  Fulfills general curriculum/education requirem...
# 3                            Interest in the subject
# 4  Fulfills general curriculum/education requirem...
#
#         Which teaching methods helped your learning?  \
# 0  Lectures, including online lectures;Class disc...
# 1  Lectures, including online lectures;Class disc...
# 2  Lectures, including online lectures;Class disc...
# 3  Lectures, including online lectures;Teamwork o...
# 4  Lectures, including online lectures;Class disc...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          5-6 hours
# 1                                         9-10 hours
# 2                                          7-8 hours
# 3                                 Less than one hour
# 4                                 Less than one hour
#
#    ... Would more faculty concern improve your learning in C01?  \
# 0  ...                                                 NO
# 1  ...                                                 NO
# 2  ...                                                Yes
# 3  ...                                                 NO
# 4  ...                                                Yes
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                Yes
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C03?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C04?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Your overall feedback about the course  \
# 0                        Good (70 - 90%)
# 1                      Excellent (> 90%)
# 2                      Excellent (> 90%)
# 3                        Good (70 - 90%)
# 4                      Excellent (> 90%)
#
#      Write a paragraph about your course experience.
# 0  It was different but go to learn to analyze th...
# 1                                       It was nice.
# 2                                               Good
# 3  this course was very intersesting to learn . a...
# 4  Overall feedback about the course is good and ...
#
# [5 rows x 45 columns]

# %%
# Strip whitespace and newline characters from all column names
data3.columns = data3.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping3 = {
    'R1': 'Happy as I put in the required effort',
    'R2': 'Happy as I understood the teacher',
    'R3': 'Happy as I enjoyed doing the CO activities',
    'R4': 'Neutral with my effort',
    'R5': 'Neutral about understanding the teacher',
    'R6': 'Neutral about the activities',
    'R7': 'Not happy as I did not put in the required effort',
    'R8': 'Not happy as I could not understand the teacher',
    'R9': 'Not happy as the CO activities were boring' 
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify3 = [
     'How satisfied are you with C01?', 'How satisfied are you with C02?',
       'How satisfied are you with C03?', 'How satisfied are you with C04?'
]

# Replace the values in the specified columns
for column in columns_to_modify3:
    if column in data3.columns:
        data3[column] = data3[column].replace(value_mapping3)

# %%
# Print the modified columns to verify the changes
print(data3[columns_to_modify3].head())
# Out:
#               How satisfied are you with C01?  \
# 0       Happy as I put in the required effort
# 1       Happy as I put in the required effort
# 2           Happy as I understood the teacher
# 3  Happy as I enjoyed doing the CO activities
# 4           Happy as I understood the teacher
#
#               How satisfied are you with C02?  \
# 0           Happy as I understood the teacher
# 1       Happy as I put in the required effort
# 2           Happy as I understood the teacher
# 3           Happy as I understood the teacher
# 4  Happy as I enjoyed doing the CO activities
#
#               How satisfied are you with C03?  \
# 0           Happy as I understood the teacher
# 1       Happy as I put in the required effort
# 2           Happy as I understood the teacher
# 3           Happy as I understood the teacher
# 4  Happy as I enjoyed doing the CO activities
#
#               How satisfied are you with C04?
# 0           Happy as I understood the teacher
# 1       Happy as I put in the required effort
# 2           Happy as I understood the teacher
# 3  Happy as I enjoyed doing the CO activities
# 4  Happy as I enjoyed doing the CO activities

# %%
 # Strip whitespace and newline characters from all column names
data3.columns = data3.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping3 = {
    'R1': 'Copy-paste friends work',
    'R2': 'Copy-paste from online',
    'R3': 'Understand others work but redo it, referring to it',
    'R4': 'Understand others work but redo it, without referring to it',
    'R5': 'Try by myself and get it reviewed by peers/teaching assistants/teachers'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify3 = [
     'List strategies for learning the course outcomes for C01',
       'List strategies for learning the course outcomes for C02',
       'List strategies for learning the course outcomes for C03',
       'List strategies for learning the course outcomes for C04'
]

# Replace the values in the specified columns
for column in columns_to_modify3:
    if column in data3.columns:
        data3[column] = data3[column].replace(value_mapping3)

# %%
# Print the modified columns to verify the changes
print(data3[columns_to_modify3].head())
# Out:
#   List strategies for learning the course outcomes for C01  \
# 0  Understand others work but redo it, without re...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, referring ...
# 4  Understand others work but redo it, without re...
#
#   List strategies for learning the course outcomes for C02  \
# 0  Understand others work but redo it, without re...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, referring ...
# 4  Understand others work but redo it, without re...
#
#   List strategies for learning the course outcomes for C03  \
# 0  Understand others work but redo it, without re...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, referring ...
# 4  Understand others work but redo it, without re...
#
#   List strategies for learning the course outcomes for C04
# 0  Try by myself and get it reviewed by peers/tea...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, referring ...
# 4  Understand others work but redo it, without re...

# %%
 # Strip whitespace and newline characters from all column names
data3.columns = data3.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping3 = {
    'R1': 'Copy-paste friends work',
    'R2': 'Copy-paste from online',
    'R3': 'Understand others work but redo it, referring to it',
    'R4': 'Understand others work but redo it, without referring to it',
    'R5': 'Try by myself and get it reviewed by peers/teaching assistants/teachers'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify3 = [
     'List strategies for learning the course outcomes for C01',
       'List strategies for learning the course outcomes for C02',
       'List strategies for learning the course outcomes for C03',
       'List strategies for learning the course outcomes for C04'
]

# Replace the values in the specified columns
for column in columns_to_modify3:
    if column in data3.columns:
        data3[column] = data3[column].replace(value_mapping3)

# %%
# Print the modified columns to verify the changes
print(data3[columns_to_modify3].head())
# Out:
#   List strategies for learning the course outcomes for C01  \
# 0  Understand others work but redo it, without re...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, referring ...
# 4  Understand others work but redo it, without re...
#
#   List strategies for learning the course outcomes for C02  \
# 0  Understand others work but redo it, without re...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, referring ...
# 4  Understand others work but redo it, without re...
#
#   List strategies for learning the course outcomes for C03  \
# 0  Understand others work but redo it, without re...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, referring ...
# 4  Understand others work but redo it, without re...
#
#   List strategies for learning the course outcomes for C04
# 0  Try by myself and get it reviewed by peers/tea...
# 1  Try by myself and get it reviewed by peers/tea...
# 2  Understand others work but redo it, without re...
# 3  Understand others work but redo it, referring ...
# 4  Understand others work but redo it, without re...

# %%
 # Strip whitespace and newline characters from all column names
data3.columns = data3.columns.str.strip()

# Define a mapping dictionary for the values
value_mapping3 = {
    'R1': 'Copy-paste friends work',
    'R2': 'Copy-paste from online',
    'R3': 'Understand others work but redo it, referring to it',
    'R4': 'Understand others work but redo it, without referring to it',
    'R5': 'Try by myself and get it reviewed by peers/teaching assistants/teachers'
}

# List of columns to modify (C01 to C04 time spent columns)
columns_to_modify3 = [
     'List strategies for learning the course outcomes for C01',
       'List strategies for learning the course outcomes for C02',
       'List strategies for learning the course outcomes for C03',
       'List strategies for learning the course outcomes for C04'
]

# Replace the values in the specified columns
for column in columns_to_modify3:
    if column in data3.columns:
        data3[column] = data3[column].replace(value_mapping3)

# %%
data3.head()
# Out:
#              USN  Gender  Age 12th marks % rural/ urban area Section  \
# 0   1RVUBSC23016  Female   23           74             Urban   IDA_B
# 1   1RVU23BSC061    Male   19          83%             Urban   IDA_B
# 2   1RVU23BSC073    Male   20           65             Rural   IDA_A
# 3   1RVU23BSC157  Female   18          88%             Urban   IDA_B
# 4  1RVU23BSC088   Female   18       93.33%             Urban   IDA_C
#
#                                Why take this course?  \
# 0  Fulfills general curriculum/education requirem...
# 1  Required (Core) for Program, Minor, or Special...
# 2  Fulfills general curriculum/education requirem...
# 3                            Interest in the subject
# 4  Fulfills general curriculum/education requirem...
#
#         Which teaching methods helped your learning?  \
# 0  Lectures, including online lectures;Class disc...
# 1  Lectures, including online lectures;Class disc...
# 2  Lectures, including online lectures;Class disc...
# 3  Lectures, including online lectures;Teamwork o...
# 4  Lectures, including online lectures;Class disc...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          5-6 hours
# 1                                         9-10 hours
# 2                                          7-8 hours
# 3                                 Less than one hour
# 4                                 Less than one hour
#
#    ... Would more faculty concern improve your learning in C01?  \
# 0  ...                                                 NO
# 1  ...                                                 NO
# 2  ...                                                Yes
# 3  ...                                                 NO
# 4  ...                                                Yes
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                Yes
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C03?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C04?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Your overall feedback about the course  \
# 0                        Good (70 - 90%)
# 1                      Excellent (> 90%)
# 2                      Excellent (> 90%)
# 3                        Good (70 - 90%)
# 4                      Excellent (> 90%)
#
#      Write a paragraph about your course experience.
# 0  It was different but go to learn to analyze th...
# 1                                       It was nice.
# 2                                               Good
# 3  this course was very intersesting to learn . a...
# 4  Overall feedback about the course is good and ...
#
# [5 rows x 45 columns]

# %%
data.head()
# Out:
#             USN  Gender  Age 12th marks % rural/ urban area Section  \
# 0  1RVU23BSC147    Male   18           75             Urban   IDA_C
# 1  1RVUBSC23016  Female   23           74             Urban   IDA_B
# 2  1RVU23BSC073    Male   20           65             Rural   IDA_A
# 3           140  Female   20           72             Urban   IDA_B
# 4  1RVU23BSC001    Male   18         70.4             Urban   IDA_B
#
#                                Why take this course?  \
# 0  Fulfills general curriculum/education requirem...
# 1  Fulfills general curriculum/education requirem...
# 2  Fulfills general curriculum/education requirem...
# 3  Fulfills general curriculum/education requirem...
# 4                            Interest in the subject
#
#         Which teaching methods helped your learning?  \
# 0  Lectures, including online lectures;Class disc...
# 1  Lectures, including online lectures;Class disc...
# 2  Lectures, including online lectures;Class disc...
# 3  Lectures, including online lectures;Class disc...
# 4  Lectures, including online lectures;Class disc...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          3-4 hours
# 1                                          5-6 hours
# 2                                          7-8 hours
# 3                                          1-2 hours
# 4                                          1-2 hours
#
#    ... Explain briefly your rationale for you choice to the previous question  \
# 0  ...  As I enjoyed learning this subject and I learn...
# 1  ...  For any student themselves or the way of teach...
# 2  ...  I will blame myself beacuse the teachers gave ...
# 3  ...                                                Nil
# 4  ...  Understood the subject due to practice and the...
#
#   Would more faculty concern improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C04? Your overall feedback
# 0                                                 NO        Excellent (> 90%)
# 1                                                Yes          Good (70 - 90%)
# 2                                                Yes        Excellent (> 90%)
# 3                                                 NO        Excellent (> 90%)
# 4                                                 NO        Excellent (> 90%)
#
# [5 rows x 43 columns]

# %%
data2.head()
# Out:
#             USN rural/ urban area  \
# 0  1RVU23CSE510             Urban
# 1  1RVU23CSE074             Urban
# 2  1RVU23CSE281             Urban
# 3  1RVU23CSE517             Rural
# 4  1RVU23CSE045             Urban
#
#         Which teaching methods helped your learning?  \
# 0  Class discussions, including online discussion...
# 1  In-class learning activities, other than discu...
# 2  Class discussions, including online discussion...
# 3  Lectures, including online lectures;In-class c...
# 4  Class discussions, including online discussion...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          3-4 hours
# 1                                          1-2 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C02?  \
# 0                                          3-4 hours
# 1                                          1-2 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C03?  \
# 0                                          5-6 hours
# 1                                          3-4 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          1-2 hours
#
#   How much time did you spend weekly on this course outside of class for C04?  \
# 0                                          7-8 hours
# 1                                          3-4 hours
# 2                                                NaN
# 3                                          3-4 hours
# 4                                          3-4 hours
#
#   What level have you achieved in the course outcomes for C01?  \
# 0                  Thinking creatively or critically
# 1                                   Solving problems
# 2  Making judgments about the value of informatio...
# 3                  Thinking creatively or critically
# 4  Making judgments about the value of informatio...
#
#   What level have you achieved in the course outcomes for C02?  ...  \
# 0  Applying theories or concepts to practical pro...            ...
# 1                                   Solving problems            ...
# 2  Making judgments about the value of informatio...            ...
# 3                  Thinking creatively or critically            ...
# 4  Making judgments about the value of informatio...            ...
#
#   Would more faculty concern improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                 NO
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
#
#   Would more outside help improve your learning in C01?.1  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
#
#   Would more outside help improve your learning in C01?.2  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
#
#   Would more outside help improve your learning in C01?.3  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                Yes
# 4                                                 NO
#
#   Your overall feedback about the course  \
# 0                        Good (70 - 90%)
# 1                      Excellent (> 90%)
# 2                      Excellent (> 90%)
# 3                        Good (70 - 90%)
# 4                        Good (70 - 90%)
#
#      Write a paragraph about your course experience.
# 0   It helped me analyze graphs in more deeper level
# 1  Data Analysis with Python was a very useful co...
# 2                                          Excellent
# 3  It was a nice experience for me to analyse dat...
# 4                                                NaN
#
# [5 rows x 38 columns]

# %%
data3.head()
# Out:
#              USN  Gender  Age 12th marks % rural/ urban area Section  \
# 0   1RVUBSC23016  Female   23           74             Urban   IDA_B
# 1   1RVU23BSC061    Male   19          83%             Urban   IDA_B
# 2   1RVU23BSC073    Male   20           65             Rural   IDA_A
# 3   1RVU23BSC157  Female   18          88%             Urban   IDA_B
# 4  1RVU23BSC088   Female   18       93.33%             Urban   IDA_C
#
#                                Why take this course?  \
# 0  Fulfills general curriculum/education requirem...
# 1  Required (Core) for Program, Minor, or Special...
# 2  Fulfills general curriculum/education requirem...
# 3                            Interest in the subject
# 4  Fulfills general curriculum/education requirem...
#
#         Which teaching methods helped your learning?  \
# 0  Lectures, including online lectures;Class disc...
# 1  Lectures, including online lectures;Class disc...
# 2  Lectures, including online lectures;Class disc...
# 3  Lectures, including online lectures;Teamwork o...
# 4  Lectures, including online lectures;Class disc...
#
#   Were you prepared to take this course based on prior coursework?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   How much time did you spend weekly on this course outside of class for C01?  \
# 0                                          5-6 hours
# 1                                         9-10 hours
# 2                                          7-8 hours
# 3                                 Less than one hour
# 4                                 Less than one hour
#
#    ... Would more faculty concern improve your learning in C01?  \
# 0  ...                                                 NO
# 1  ...                                                 NO
# 2  ...                                                Yes
# 3  ...                                                 NO
# 4  ...                                                Yes
#
#   Would more faculty concern improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C03?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Would more faculty concern improve your learning in C04?  \
# 0                                                Yes
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Would more outside help improve your learning in C01?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C02?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C03?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                 NO
#
#   Would more outside help improve your learning in C04?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                Yes
# 3                                                 NO
# 4                                                Yes
#
#   Your overall feedback about the course  \
# 0                        Good (70 - 90%)
# 1                      Excellent (> 90%)
# 2                      Excellent (> 90%)
# 3                        Good (70 - 90%)
# 4                      Excellent (> 90%)
#
#      Write a paragraph about your course experience.
# 0  It was different but go to learn to analyze th...
# 1                                       It was nice.
# 2                                               Good
# 3  this course was very intersesting to learn . a...
# 4  Overall feedback about the course is good and ...
#
# [5 rows x 45 columns]

# %%
# Merge the dataframes (row-wise or column-wise, depending on your need)
# For row-wise (assuming the same columns):
merged_df = pd.concat([data, data2, data3], ignore_index=True)

# If you want to merge them based on a common column (key):
# merged_df = pd.merge(df1, df2, on='common_column')
# merged_df = pd.merge(merged_df, df3, on='common_column')

# Save the merged dataframe to a new CSV file
merged_df.to_csv('StudentFeedback.csv', index=False)

print("Files merged successfully!")
# Out:
# Files merged successfully!
